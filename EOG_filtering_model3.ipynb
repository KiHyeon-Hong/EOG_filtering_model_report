# %%
def featureExtraction(fileDir, minCount, maxCount, leftLight):
    userHp1 = []
    userLp1 = []
    userLhpl1 = []
    userLlpl1 = []
    userHpl1 = []
    userLpl1 = []
    userLhpg1 = []
    userLlpg1 = []
    userRhpg1 = []
    userRlpg1 = []
    userBlink1 = []
    userNotBlink1 = []
    
    for count in range(minCount, maxCount):
        file = open(fileDir + '/file' + str(count) + '-' + str(leftLight) + '.txt', 'r')
        x = file.read()
        file.close()
    
        x = x.split(',')
    
        data1 = []
    
        for index, item in enumerate(x):
            data1.append(float(item))
        
        for index, item in enumerate(x):
            if(index != len(data1) -1):
                data1[index] = data1[index + 1]
            
        temp = 0
        index = 0

        start1 = []
        middle1 = []
        finish1 = []

        for i in range(0, len(data1)):
            if((temp + 150 < i) and (data1[i] > 100)):
                for j in range(i, 0, -1):
                    if(data1[j] <= 0):
                        start1.append(j)
                        break
                
                for j in range(start1[index] + 1, len(data1)):
                    if(data1[j] <= 0):
                        middle1.append(j)
                        break
                
                for j in range(middle1[index] + 1, len(data1)):
                    if(data1[j] >= 0):
                        finish1.append(j)
                        break
                
                i = finish1[index]
                index = index + 1
                temp = i
   
        temp = 0
    
        hp1 = []
        lp1 = []
        lhpl1 = []
        llpl1 = []
        hpl1 = []
        lpl1 = []
        lhpg1 = []
        llpg1 = []
        rhpg1 = []
        rlpg1 = []
        blink1 = []
        notBlink1 = []
    
        index = 0;
    
        for i in range(start1[0], finish1[len(finish1) - 1]):
            hp1.append(0)
            lp1.append(0)
            lhpl1.append(0)
            llpl1.append(0)
            hpl1.append(0)
            lpl1.append(0)
            lhpg1.append(0)
            llpg1.append(0)
            rhpg1.append(0)
            rlpg1.append(0)
            blink1.append(0)
            notBlink1.append(0)
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] < data1[j]):
                    hp1[index] = data1[j]
                    lhpl1[index] = j - start1[index]
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] > data1[j]):
                    lp1[index] = data1[j]
                    llpl1[index] = j - start1[index]
            
            hpl1[index] = middle1[index] - start1[index]
            lpl1[index] = finish1[index] - middle1[index]
    
            lhpg1[index] = hp1[index] / lhpl1[index]
            llpg1[index] = lp1[index] / llpl1[index]
            rhpg1[index] = hp1[index] / (hpl1[index] - lhpg1[index])
            rlpg1[index] = lp1[index] / (lpl1[index] - llpl1[index])
    
            index = index + 1
    
            if(len(start1) == index):
                break
    
            i = start1[index]
        
        index = 0;
        
        for i in range(0, len(finish1)):
            blink1[i] = finish1[i] - start1[i]

        for i in range(0, len(finish1) - 1):
            notBlink1[i] = start1[i + 1] - finish1[i]
        
        for i in range(0, len(finish1)):
            userHp1.append(hp1[i])
            userLp1.append(lp1[i])
            userLhpl1.append(lhpl1[i])
            userLlpl1.append(llpl1[i])
            userHpl1.append(hpl1[i])
            userLpl1.append(lpl1[i])
            userLhpg1.append(lhpg1[i])
            userLlpg1.append(llpg1[i])
            userRhpg1.append(rhpg1[i])
            userRlpg1.append(rlpg1[i])
            userBlink1.append(blink1[i])
            userNotBlink1.append(notBlink1[i])
            
    return userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1

# %%
user1Data  = []
user1Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user1', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user1', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user1Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user1Label.append(0)

# %%
user2Data  = []
user2Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user2', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user2', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user2Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user2Label.append(1)

# %%
user3Data  = []
user3Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user3Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user3Label.append(2)

# %%
import numpy as np

# %%
user1Data = np.array(user1Data)
user2Data = np.array(user2Data)
user3Data = np.array(user3Data)

user1Label = np.array(user1Label)
user2Label = np.array(user2Label)
user3Label = np.array(user3Label)

# %%
data = np.concatenate((user1Data, user2Data, user3Data), axis=0)

# %%
len(data)
# Out:
# 3239

# %%
label = np.concatenate((user1Label, user2Label, user3Label), axis=0)

# %%
len(label)
# Out:
# 3239

# %%
s = np.arange(data.shape[0])
np.random.shuffle(s)

# %%
data = data[s]
label = label[s]

# %%
label
# Out:
# array([1, 0, 1, ..., 1, 1, 2])

# %%
tempLabel = []

# %%
for i in range(0, len(label)):
    if(label[i] == 0):
        tempLabel.append([1, 0, 0])
    elif(label[i] == 1):
        tempLabel.append([0, 1, 0])
    else:
        tempLabel.append([0, 0, 1])

# %%
label = tempLabel

# %%
label = np.array(label)

# %%
train_data = data[:2500]
val_data = data[2500:]

train_label = label[:2500]
val_label = label[2500:]

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

val_data -= mean
val_data /= std

# %%
from keras import models
from keras import layers
from keras import regularizers
from keras import optimizers

# %%
def build_model(actiFunc, lossFunc, hidden, node, dropout):
    model = models.Sequential()
    
    model.add(layers.Dense(node[0], activation=actiFunc, input_shape=(12, )))
    model.add(layers.Dropout(dropout))
    
    if(hidden == 2):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    if(hidden == 3):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
        model.add(layers.Dense(node[2], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='rmsprop', loss=lossFunc, metrics=['accuracy'])
    return model

# %%
import numpy as np

num_epochs = 100


actiFunc = ['selu', 'relu']
lossFunc = ['categorical_crossentropy']
hidden = [1, 2, 3]
#node = [[4, 4], [4, 8], [4, 16], [4, 32], [8, 4], [8, 8], [8, 16], [8, 32], [16, 4], [16, 8], [16, 16], [16, 32], [32, 4], [32, 8], [32, 16], [32, 32]]
node = [
    [4, 4, 4], [4, 4, 8], [4, 4, 16], [4, 4, 32], [4, 8, 4], [4, 8, 8], [4, 8, 16], [4, 8, 32], [4, 16, 4], [4, 16, 8], [4, 16, 16], [4, 16, 32], [4, 32, 4], [4, 32, 8], [4, 32, 16], [4, 32, 32],
    [8, 4, 4], [8, 4, 8], [8, 4, 16], [8, 4, 32], [8, 8, 4], [8, 8, 8], [8, 8, 16], [8, 8, 32], [8, 16, 4], [8, 16, 8], [8, 16, 16], [8, 16, 32], [8, 32, 4], [8, 32, 8], [8, 32, 16], [8, 32, 32],
    [16, 4, 4], [16, 4, 8], [16, 4, 16], [16, 4, 32], [16, 8, 4], [16, 8, 8], [16, 8, 16], [16, 8, 32], [16, 16, 4], [16, 16, 8], [16, 16, 16], [16, 16, 32], [16, 32, 4], [16, 32, 8], [16, 32, 16], [16, 32, 32],
    [32, 4, 4], [32, 4, 8], [32, 4, 16], [32, 4, 32], [32, 8, 4], [32, 8, 8], [32, 8, 16], [32, 8, 32], [32, 16, 4], [32, 16, 8], [32, 16, 16], [32, 16, 32], [32, 32, 4], [32, 32, 8], [32, 32, 16], [32, 32, 32]
]
batchSize = [512]
dropout = [0, 0.1, 0.3]

all_acc_histories = []
all_loss_histories = []

for i in range(len(actiFunc)):
    for j in range(len(lossFunc)):
        for k in range(len(hidden)):
            for l in range(len(node)):
                for m in range(len(batchSize)):
                    for n in range(len(dropout)):
                        print('Activation:', actiFunc[i] , '  Loss:', lossFunc[j] , '  HiddenLayer:', hidden[k] , '  Node:[', node[l][0], ',', node[l][1] , ',', node[l][2], ']  BatchSize:', batchSize[m], '  Dropout:', dropout[n])
    
                        model = build_model(actiFunc[i], lossFunc[j], hidden[k], node[l], dropout[n])
                        history = model.fit(train_data, train_label, validation_data=(val_data, val_label), epochs=num_epochs, batch_size=batchSize[m], verbose=False)
    
                        acc_history = history.history['val_acc']
                        all_acc_histories.append(acc_history)
                        loss_history = history.history['val_loss']
                        all_loss_histories.append(loss_history)
    
                        print('loss min :', min(loss_history), '  acc max:', max(acc_history))
                        print('loss mean :', np.mean(loss_history), '  acc mean:', np.mean(acc_history))
    
                        print()
# Out:
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5789053127956003   acc max: 0.8660351770333895
# loss mean : 0.7774218863377874   acc mean: 0.7599729349088122
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5786372140876657   acc max: 0.8579161030836454
# loss mean : 0.7843322769674461   acc mean: 0.7285926921224078
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6169034717692735   acc max: 0.8579161030836454
# loss mean : 0.93405818612069   acc mean: 0.675967525463748
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5451616998131769   acc max: 0.8660351748556826
# loss mean : 0.7211633552112824   acc mean: 0.794695532674799
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5523606217762452   acc max: 0.8619756473578684
# loss mean : 0.7644750974384793   acc mean: 0.7233694185082662
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6015736096928019   acc max: 0.7848443876100006
# loss mean : 0.8872367261251352   acc mean: 0.640473614854887
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5873914184363833   acc max: 0.8565629311762901
# loss mean : 0.6690216444495243   acc mean: 0.8352909378277915
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5590840103016493   acc max: 0.8633288170875167
# loss mean : 0.8344482989877422   acc mean: 0.691989173497173
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6315676611879681   acc max: 0.8538565588094224
# loss mean : 0.9585331656185958   acc mean: 0.6774560202519045
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.531447887138359   acc max: 0.8646820007706205
# loss mean : 0.758387247610318   acc mean: 0.7506630581127368
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6110417763822295   acc max: 0.8457374833272178
# loss mean : 0.8113579833838226   acc mean: 0.750635993766607
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5581715474754613   acc max: 0.8633288229753909
# loss mean : 0.6985086396437374   acc mean: 0.7851962105153539
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5399887452106192   acc max: 0.8673883591840329
# loss mean : 0.7241817307633542   acc mean: 0.7526928276771297
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.55121178402791   acc max: 0.8592692852342887
# loss mean : 0.7072294728705942   acc mean: 0.768985114058074
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5664316373039163   acc max: 0.8592692830565818
# loss mean : 0.7784884265174079   acc mean: 0.7526657633920965
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5304914549981145   acc max: 0.867388367249614
# loss mean : 0.8039554789101806   acc mean: 0.7516102845307456
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5755906700281394   acc max: 0.8592692749910006
# loss mean : 0.7023910181843378   acc mean: 0.7732340973591453
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5821312447362081   acc max: 0.8687415450448435
# loss mean : 0.8068845752038878   acc mean: 0.7259539917950216
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5433237004989862   acc max: 0.8606224710950994
# loss mean : 0.7446118274351258   acc mean: 0.7475507467239084
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5635388524187112   acc max: 0.8619756349368735
# loss mean : 0.8520115749382683   acc mean: 0.6907442484096356
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.593329648768305   acc max: 0.8565629172228347
# loss mean : 0.9105265755050076   acc mean: 0.6299729358012685
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6233888212011696   acc max: 0.8565629311762901
# loss mean : 0.8852846695928355   acc mean: 0.684465494404707
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5459814965321667   acc max: 0.8511502112845445
# loss mean : 0.8292528975066378   acc mean: 0.7075101497329783
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5916916750603342   acc max: 0.8538565609871293
# loss mean : 0.7647187365109608   acc mean: 0.7771177265781993
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5993223164497757   acc max: 0.8552097350721914
# loss mean : 0.7946887102727154   acc mean: 0.7359269293945117
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5023717197900858   acc max: 0.8660351909868449
# loss mean : 0.6630725394276062   acc mean: 0.8071177275585708
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5564865896601799   acc max: 0.8714478969251351
# loss mean : 0.6889218081374615   acc mean: 0.7807307176128614
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.579848975790047   acc max: 0.8660351909868449
# loss mean : 0.7432500742898097   acc mean: 0.7941272000809161
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5313098743174814   acc max: 0.8660351850989707
# loss mean : 0.7442860611700561   acc mean: 0.733017590161065
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6816546420928429   acc max: 0.8240865950494077
# loss mean : 0.879430675095247   acc mean: 0.68553450690474
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5469220896857678   acc max: 0.8619756349368735
# loss mean : 0.7393168614189743   acc mean: 0.7746820010170237
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5414987637967638   acc max: 0.8660351850989707
# loss mean : 0.7143285526869583   acc mean: 0.7595263858536743
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5901416280434161   acc max: 0.8619756349368735
# loss mean : 0.8269501493183621   acc mean: 0.7389851146145987
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5473892032212915   acc max: 0.8619756408247476
# loss mean : 0.7038902167127   acc mean: 0.7873883622566157
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5569379740219478   acc max: 0.8538565712304174
# loss mean : 0.7193119265544398   acc mean: 0.6989580532924572
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.606336337465072   acc max: 0.849797023246027
# loss mean : 0.7829698939889629   acc mean: 0.6460081182216598
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5414874623850976   acc max: 0.856562920933002
# loss mean : 0.964897385550126   acc mean: 0.6113261162437226
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5512014940401214   acc max: 0.8646820007706205
# loss mean : 0.7678690102111664   acc mean: 0.7598105554575043
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5523362784811544   acc max: 0.8687415472225504
# loss mean : 0.7073662840537677   acc mean: 0.7696887676274666
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5610856075893397   acc max: 0.8646820051260343
# loss mean : 0.8425842609182906   acc mean: 0.7253044655453287
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5552390080666187   acc max: 0.863328825153098
# loss mean : 0.6748624033405268   acc mean: 0.7880243565087713
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5659266875625786   acc max: 0.8592692749910006
# loss mean : 0.7457106932566195   acc mean: 0.7354262520415211
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5720581465548205   acc max: 0.8579161009059385
# loss mean : 0.7446260015753191   acc mean: 0.8026116365391927
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.52748886763001   acc max: 0.8646820051260343
# loss mean : 0.6209941058971885   acc mean: 0.8471853842972417
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5491784114153685   acc max: 0.8633288149098098
# loss mean : 0.767697162379754   acc mean: 0.7488903921729656
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5156361993417365   acc max: 0.8579161052613523
# loss mean : 0.7296600983075104   acc mean: 0.7543301751330515
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5809132219651394   acc max: 0.8511502010412565
# loss mean : 0.6975599249677181   acc mean: 0.8081326130222084
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5868993800773672   acc max: 0.8565629150451278
# loss mean : 0.7300750710507691   acc mean: 0.7209066284650558
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.482975657560506   acc max: 0.8687415369792624
# loss mean : 0.7149446921963976   acc mean: 0.7584167778016103
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4968705324503985   acc max: 0.8714478969251351
# loss mean : 0.6594378696787341   acc mean: 0.8015832213210559
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5226356126216816   acc max: 0.8673883570063259
# loss mean : 0.6382387864045265   acc mean: 0.8279025705088139
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5013528292814675   acc max: 0.8741542568710079
# loss mean : 0.6121920703075251   acc mean: 0.8362381573208936
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5056481586015595   acc max: 0.8741542649365891
# loss mean : 0.7805442300313863   acc mean: 0.7457645477594478
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.541079765324341   acc max: 0.8619756430024546
# loss mean : 0.6813152137047868   acc mean: 0.8355345041035638
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.49689668098386475   acc max: 0.8660351829212638
# loss mean : 0.7369241621134567   acc mean: 0.7753044662780869
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5020285399179497   acc max: 0.8619756451801615
# loss mean : 0.636972629315395   acc mean: 0.77937753802425
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5289495625257169   acc max: 0.8700947250177798
# loss mean : 0.635533478055981   acc mean: 0.8352097403236914
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5469552359981047   acc max: 0.8552097431377725
# loss mean : 0.7840021110556927   acc mean: 0.7336400541102615
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5010395212570289   acc max: 0.8687415348015555
# loss mean : 0.6756467142636624   acc mean: 0.7947225963141824
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5382267078624204   acc max: 0.8741542627588822
# loss mean : 0.7273007811325652   acc mean: 0.7893234100623286
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4942661434291019   acc max: 0.8633288149098098
# loss mean : 0.5975800004081249   acc mean: 0.8364276018613728
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48705169078623006   acc max: 0.8714479049907163
# loss mean : 0.5893410869952951   acc mean: 0.8303112311489851
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5648837525079957   acc max: 0.867388354828619
# loss mean : 0.7132084879267039   acc mean: 0.7774424920655555
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4949593545619464   acc max: 0.8728010849636527
# loss mean : 0.6550190514160751   acc mean: 0.7559945881104597
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5463784445122549   acc max: 0.8660351748556826
# loss mean : 0.652364732678753   acc mean: 0.8319621140539081
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5528826019922032   acc max: 0.8592692749910006
# loss mean : 0.6853514621520721   acc mean: 0.8168200288690801
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5344309672128525   acc max: 0.8538565550992551
# loss mean : 0.7531643930613915   acc mean: 0.7575913385935985
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5053731584984491   acc max: 0.8741542590487148
# loss mean : 0.6134733146941226   acc mean: 0.8377943189133648
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5166177353613755   acc max: 0.8714479049907163
# loss mean : 0.6467347245464791   acc mean: 0.836806495886533
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5378069425145409   acc max: 0.8687415348015555
# loss mean : 0.7497626827969763   acc mean: 0.7530987827034217
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5348973112919334   acc max: 0.859269291122163
# loss mean : 0.6335393365156989   acc mean: 0.8440460105347215
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5173358610744244   acc max: 0.8646819948827462
# loss mean : 0.6566482344854507   acc mean: 0.7996617019612023
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5394693944547754   acc max: 0.8619756510680358
# loss mean : 0.704885082155345   acc mean: 0.7917591371821774
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.49797323858302406   acc max: 0.867388354828619
# loss mean : 0.6064415031526343   acc mean: 0.8296752367274526
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5340077445536086   acc max: 0.874154267114296
# loss mean : 0.6733150580577824   acc mean: 0.7913531780634102
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5595057274395139   acc max: 0.860622454963937
# loss mean : 0.9203474403613314   acc mean: 0.7148173193111308
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4988661350755472   acc max: 0.8741542568710079
# loss mean : 0.7288167311313671   acc mean: 0.7576725284981066
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5454914737618825   acc max: 0.8660351909868449
# loss mean : 0.6484016570791663   acc mean: 0.8197428971750809
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4886621089201012   acc max: 0.8714478969251351
# loss mean : 0.6365434988510464   acc mean: 0.8046278747920254
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48686878147241386   acc max: 0.874154267114296
# loss mean : 0.6309114793350313   acc mean: 0.8234776705717199
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5061354251611216   acc max: 0.8687415450448435
# loss mean : 0.7233866096873729   acc mean: 0.7741542633960629
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5475759867563622   acc max: 0.8700947228400729
# loss mean : 0.6759975090522081   acc mean: 0.8138700935361513
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5251585040266685   acc max: 0.8660351748556826
# loss mean : 0.670517383520271   acc mean: 0.7492286878247546
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5286187951393798   acc max: 0.8660351829212638
# loss mean : 0.6292614895879658   acc mean: 0.8166035186357203
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.49386224723313915   acc max: 0.8768606168168808
# loss mean : 0.6323427087540394   acc mean: 0.830216508678719
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5114801227643139   acc max: 0.863328825153098
# loss mean : 0.6051376023840195   acc mean: 0.8138430306888078
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.555352212772963   acc max: 0.8646820051260343
# loss mean : 0.7174152745429491   acc mean: 0.7983085254467869
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.515238325029652   acc max: 0.8700947147744919
# loss mean : 0.6648757886067941   acc mean: 0.7976995944424315
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5385270146136355   acc max: 0.8633288310409721
# loss mean : 0.6790749063333736   acc mean: 0.8043031126022824
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5581204658916097   acc max: 0.8646820051260343
# loss mean : 0.6527679200738628   acc mean: 0.8218944507651789
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4966540052297151   acc max: 0.8633288273308048
# loss mean : 0.6285944411844135   acc mean: 0.796238161376671
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5562923557058239   acc max: 0.8619756510680358
# loss mean : 0.7447796455610428   acc mean: 0.789147497127198
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5436112089473275   acc max: 0.8619756349368735
# loss mean : 0.9130626507234507   acc mean: 0.6936129903912301
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48143109534041645   acc max: 0.8741542568710079
# loss mean : 0.5961009701005661   acc mean: 0.828998645270629
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.542947511469721   acc max: 0.8592692749910006
# loss mean : 0.6718734181306358   acc mean: 0.7758457380307381
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5294170665160245   acc max: 0.8619756451801615
# loss mean : 0.6456498460259908   acc mean: 0.8198376202091313
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.49023069443334905   acc max: 0.8728010768980715
# loss mean : 0.5955204221578024   acc mean: 0.8410554771893562
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5015659225003161   acc max: 0.8660351807435569
# loss mean : 0.6066717294749776   acc mean: 0.8308119089830872
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4914621295803132   acc max: 0.8768606270601688
# loss mean : 0.588872021022927   acc mean: 0.8451285527737279
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4799364085368439   acc max: 0.8836265188592697
# loss mean : 0.621753540445971   acc mean: 0.8022598108104827
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5004045459995089   acc max: 0.8755074470872324
# loss mean : 0.6082388260835563   acc mean: 0.8260351809492289
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5312259329510638   acc max: 0.8633288229753909
# loss mean : 0.6104773965231944   acc mean: 0.8443166444217722
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4906172271671734   acc max: 0.880920166978978
# loss mean : 0.6100818004353282   acc mean: 0.8482543982894073
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4654674934921471   acc max: 0.8782138070331053
# loss mean : 0.562287366936268   acc mean: 0.8485520971200464
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5259559930419405   acc max: 0.8619756510680358
# loss mean : 0.598056017776626   acc mean: 0.8317591358384518
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.464214591196006   acc max: 0.8768606248824619
# loss mean : 0.6243042717859936   acc mean: 0.8199864687537713
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4798201305214542   acc max: 0.8673883570063259
# loss mean : 0.6442063516555847   acc mean: 0.800568335986468
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.49550137125429505   acc max: 0.8660351748556826
# loss mean : 0.5778216963619276   acc mean: 0.8454939069226888
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4915451371137441   acc max: 0.8633288229753909
# loss mean : 0.6390042247093901   acc mean: 0.8056562954550341
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5112674237104166   acc max: 0.8741542568710079
# loss mean : 0.6325877016355285   acc mean: 0.8328416784912228
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.50978557618287   acc max: 0.8728010849636527
# loss mean : 0.6087187973209259   acc mean: 0.8074018967679936
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4588585061617246   acc max: 0.8795669789404604
# loss mean : 0.6713270974933537   acc mean: 0.7771989161941613
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.49417505261055994   acc max: 0.8673883650719071
# loss mean : 0.5898517379100172   acc mean: 0.8314885005867043
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5289139254006062   acc max: 0.8673883570063259
# loss mean : 0.5896732623933617   acc mean: 0.8455886348505304
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4380079377165344   acc max: 0.8890392387510152
# loss mean : 0.5339119537096062   acc mean: 0.8504871445507094
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5073657773021755   acc max: 0.8660351748556826
# loss mean : 0.6603436562697199   acc mean: 0.8112990554532032
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5121379557175307   acc max: 0.8700947228400729
# loss mean : 0.6168714408094569   acc mean: 0.8482002719224551
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4548495115866035   acc max: 0.8836265166815628
# loss mean : 0.6257348560524728   acc mean: 0.8157780767513466
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.47639147648953295   acc max: 0.8768606248824619
# loss mean : 0.6071118604479527   acc mean: 0.8291880903793286
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5297413392544438   acc max: 0.8700947271954869
# loss mean : 0.6614621015846809   acc mean: 0.8140189440566568
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.49125176539117815   acc max: 0.8795669870060416
# loss mean : 0.6083195605999078   acc mean: 0.8334912039849692
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4847337683821563   acc max: 0.874154267114296
# loss mean : 0.5724177451373275   acc mean: 0.8376184039412717
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4994138027560243   acc max: 0.8741542649365891
# loss mean : 0.664754592291557   acc mean: 0.8081055460194775
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48388827895601966   acc max: 0.8714478947474282
# loss mean : 0.6077618136445466   acc mean: 0.823301758232233
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.49080929027036013   acc max: 0.8714478969251351
# loss mean : 0.5773324199897995   acc mean: 0.8343437060750063
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.513942375315381   acc max: 0.8700947228400729
# loss mean : 0.6136606201315765   acc mean: 0.8408931004347755
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4662458568771089   acc max: 0.8836265291025577
# loss mean : 0.5568041995087076   acc mean: 0.8497970202407913
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48294879748146974   acc max: 0.8809201567356899
# loss mean : 0.5762095699815207   acc mean: 0.8423680628902694
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5040365578115228   acc max: 0.8714479093461301
# loss mean : 0.6762474227645238   acc mean: 0.7982814615593874
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48999514058736404   acc max: 0.8728010849636527
# loss mean : 0.6232285861620561   acc mean: 0.8273342337990647
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4660503072651539   acc max: 0.880920166978978
# loss mean : 0.5450904663453567   acc mean: 0.8592692831412703
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4940025402744665   acc max: 0.8714479049907163
# loss mean : 0.6294190607821828   acc mean: 0.8059133925812171
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4774611584630484   acc max: 0.8728010871413596
# loss mean : 0.5836972782503769   acc mean: 0.8514749667705798
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.47423723614264246   acc max: 0.8768606168168808
# loss mean : 0.568365261710787   acc mean: 0.8449526378282514
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.514758176264808   acc max: 0.8755074368439444
# loss mean : 0.6299910969405116   acc mean: 0.8310554817399571
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.47988198957681977   acc max: 0.8782137967898171
# loss mean : 0.6914201625762192   acc mean: 0.7910148836984848
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.45498193645186935   acc max: 0.8768606248824619
# loss mean : 0.5670774276677585   acc mean: 0.8358457388086634
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5038336734407164   acc max: 0.8755074368439444
# loss mean : 0.6280529426536315   acc mean: 0.8198376165723608
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4529421091160368   acc max: 0.8782138070331053
# loss mean : 0.555846720085415   acc mean: 0.8478349097938112
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4901989751239591   acc max: 0.874154267114296
# loss mean : 0.6129240860797073   acc mean: 0.8205006758080282
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4788749505928308   acc max: 0.8755074390216513
# loss mean : 0.5518217572763421   acc mean: 0.8597970229322756
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4802960696981789   acc max: 0.8714478969251351
# loss mean : 0.6038321902206689   acc mean: 0.8344790264032528
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48471130122189915   acc max: 0.8673883570063259
# loss mean : 0.601039407850925   acc mean: 0.8365764545652311
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4970127561498882   acc max: 0.8700947169521988
# loss mean : 0.6283288530196809   acc mean: 0.8345060870620006
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.41651453313711373   acc max: 0.8876860587780788
# loss mean : 0.5345969095805985   acc mean: 0.857212447315979
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.44390240146278204   acc max: 0.8822733388863333
# loss mean : 0.5289278176015543   acc mean: 0.8582002684236056
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.45685513827733   acc max: 0.8809201691566849
# loss mean : 0.565451332991678   acc mean: 0.8467794321096312
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4382285593085102   acc max: 0.8876860587780788
# loss mean : 0.52092827336593   acc mean: 0.8640054129908953
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4437443887429244   acc max: 0.8822733469519144
# loss mean : 0.5549918247894441   acc mean: 0.8466982412769767
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4872303676056765   acc max: 0.8728010768980715
# loss mean : 0.5703666667388161   acc mean: 0.8487415410273775
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4160872653872783   acc max: 0.8917456089401762
# loss mean : 0.5133660344716984   acc mean: 0.8628281474339302
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4701366486262243   acc max: 0.8782137967898171
# loss mean : 0.60212144313549   acc mean: 0.818457376538941
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4768294684780467   acc max: 0.8768606168168808
# loss mean : 0.5617898543499642   acc mean: 0.8462246264511257
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.44056831294209453   acc max: 0.8863328809828493
# loss mean : 0.5429783675260086   acc mean: 0.8582273335821413
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.45352925636448943   acc max: 0.8836265291025577
# loss mean : 0.5683255206804636   acc mean: 0.8423409997898686
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4708797455801854   acc max: 0.8782138092108122
# loss mean : 0.5642900285600647   acc mean: 0.8423004078023204
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4321065016383247   acc max: 0.8944519688860489
# loss mean : 0.532522805351285   acc mean: 0.8549255750470458
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4418926516872943   acc max: 0.8930987808475314
# loss mean : 0.5495434394458635   acc mean: 0.8530040598972244
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.48768375190894886   acc max: 0.8795669789404604
# loss mean : 0.5411706804616203   acc mean: 0.8613261135174552
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.43283546704884635   acc max: 0.8849797068977873
# loss mean : 0.5476359884644555   acc mean: 0.8493504740146566
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4653548133712015   acc max: 0.8782137967898171
# loss mean : 0.562816668068927   acc mean: 0.8365899852551371
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4712896274858947   acc max: 0.8768606189945877
# loss mean : 0.5648261236297585   acc mean: 0.8469147503831712
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4315196728996721   acc max: 0.8930987786698245
# loss mean : 0.5365432209244279   acc mean: 0.862557510696906
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.43818985363304697   acc max: 0.8809201589133968
# loss mean : 0.5365544746318108   acc mean: 0.8552232730166837
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4733500818196427   acc max: 0.8809201589133968
# loss mean : 0.5871790895321696   acc mean: 0.8420297707538643
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4401612161218878   acc max: 0.8930987808475314
# loss mean : 0.5512192928504718   acc mean: 0.8546278751493308
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4305927674405791   acc max: 0.8876860609557857
# loss mean : 0.5234051271260833   acc mean: 0.8676725278816946
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4738061799490081   acc max: 0.8782138070331053
# loss mean : 0.5481385611628808   acc mean: 0.8591474953926946
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.445950623616798   acc max: 0.8714478969251351
# loss mean : 0.548168632139695   acc mean: 0.8416508782224499
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4393940392543886   acc max: 0.8849797068977873
# loss mean : 0.5481923908926799   acc mean: 0.8421650871751432
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.48127808638612696   acc max: 0.8782138070331053
# loss mean : 0.5549204458491888   acc mean: 0.8526792990056361
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.42622456789339347   acc max: 0.8903924187239517
# loss mean : 0.5294790720782357   acc mean: 0.8609472261472064
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.44097337417092797   acc max: 0.8822733491296213
# loss mean : 0.5069539115784617   acc mean: 0.8691069013590094
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4882969916754066   acc max: 0.8755074449095255
# loss mean : 0.5483257642061689   acc mean: 0.8601217855886131
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4195983521589891   acc max: 0.8890392468165964
# loss mean : 0.53158128312339   acc mean: 0.8598240839241322
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.44765854438361036   acc max: 0.8876860587780788
# loss mean : 0.5340690537093457   acc mean: 0.8584573726950867
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.47022795310201115   acc max: 0.8768606189945877
# loss mean : 0.5350711511593709   acc mean: 0.864303111336389
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.40371837941816274   acc max: 0.8903924209016586
# loss mean : 0.5289904830113799   acc mean: 0.8595805149766363
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4414278505135615   acc max: 0.8876860690213669
# loss mean : 0.5259255251473922   acc mean: 0.864871447129082
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.46577219392837144   acc max: 0.874154267114296
# loss mean : 0.5259029122352277   acc mean: 0.86508795244284
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.42420410892153626   acc max: 0.8903924311449466
# loss mean : 0.526039779728659   acc mean: 0.8552368058923615
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.46843551286825147   acc max: 0.8876860587780788
# loss mean : 0.5653372419622497   acc mean: 0.8409878202159768
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4708250744094384   acc max: 0.8795669891837485
# loss mean : 0.5420958137395256   acc mean: 0.8654668469285447
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.44712903111648816   acc max: 0.8836265291025577
# loss mean : 0.532515484031305   acc mean: 0.8633152911111369
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.46135677766251465   acc max: 0.8822733388863333
# loss mean : 0.520907145840228   acc mean: 0.8645060844576247
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.47866964045816246   acc max: 0.8795669891837485
# loss mean : 0.5671600277752128   acc mean: 0.8422327470339845
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.44636228325725086   acc max: 0.8876860690213669
# loss mean : 0.5887994364093541   acc mean: 0.8269012170023864
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4416958714289659   acc max: 0.880920166978978
# loss mean : 0.5211677612374376   acc mean: 0.8557374797533589
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.46813605324502566   acc max: 0.8741542568710079
# loss mean : 0.5361459736177177   acc mean: 0.8589309863155361
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.43464114475637394   acc max: 0.8863328788051424
# loss mean : 0.5527977802551002   acc mean: 0.8407171848154198
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4777080214233295   acc max: 0.8755074368439444
# loss mean : 0.5822946101507734   acc mean: 0.8367117712805009
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.48971752767956467   acc max: 0.8700947271954869
# loss mean : 0.5629455781055562   acc mean: 0.8483897153555299
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48344076300828803   acc max: 0.8822733469519144
# loss mean : 0.6132197130795098   acc mean: 0.8261569684034109
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5282496163099802   acc max: 0.8579161111492265
# loss mean : 0.7394477049512374   acc mean: 0.7232341002611409
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5897110995807571   acc max: 0.8538565712304174
# loss mean : 0.7470643464928548   acc mean: 0.7630852499209014
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4055691783257202   acc max: 0.8795669767627535
# loss mean : 0.589702550966459   acc mean: 0.8216779441960128
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5266019478541104   acc max: 0.8687415369792624
# loss mean : 0.7584216363036422   acc mean: 0.7825169134156147
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5353735002193787   acc max: 0.8552097431377725
# ...
# loss mean : 0.5283854286572285   acc mean: 0.8372801089165819
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5143828467845272   acc max: 0.8728010871413596
# loss mean : 0.6970395325158543   acc mean: 0.796779432350389
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3190218588496093   acc max: 0.8998646887777946
# loss mean : 0.4382511629811482   acc mean: 0.8690257122907005
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.39261335344211334   acc max: 0.891745600874595
# loss mean : 0.5273429662807869   acc mean: 0.8496346420053702
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.41970706538515257   acc max: 0.874154267114296
# loss mean : 0.5129282263566579   acc mean: 0.8428010824415453
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29762886220611967   acc max: 0.8971583266542148
# loss mean : 0.5122215622272317   acc mean: 0.8323815971292322
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.36273427841950495   acc max: 0.8863328868707236
# loss mean : 0.5446360572797518   acc mean: 0.8245602173806849
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4463489347607583   acc max: 0.8619756349368735
# loss mean : 0.5769109325225846   acc mean: 0.8194452008984082
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29846104535908113   acc max: 0.9039242308743106
# loss mean : 0.40293935192171715   acc mean: 0.8798511511764926
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3252395257575586   acc max: 0.8985115044494443
# loss mean : 0.4579636677555205   acc mean: 0.8678755061665149
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.44533649256329416   acc max: 0.8700947147744919
# loss mean : 0.5965840737547861   acc mean: 0.8216779427720343
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3152398323496559   acc max: 0.9052773984262521
# loss mean : 0.44073158038364213   acc mean: 0.8731258463722442
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3921220628027987   acc max: 0.8795669789404604
# loss mean : 0.5284980647578452   acc mean: 0.8295128552843494
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4122901021305053   acc max: 0.871447899102842
# loss mean : 0.5528968986203447   acc mean: 0.8249391057665925
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.30315493964697254   acc max: 0.9052774086695401
# loss mean : 0.3870087296460252   acc mean: 0.8854939119128638
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2976236312734581   acc max: 0.9025710406580861
# loss mean : 0.4330491314782019   acc mean: 0.877672531801567
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4164031077383013   acc max: 0.8782137967898171
# loss mean : 0.5768940471961631   acc mean: 0.8307713111039347
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29896293675302654   acc max: 0.9066305886424766
# loss mean : 0.4120906488926066   acc mean: 0.874316644095923
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3211219666855906   acc max: 0.8917455986968881
# loss mean : 0.43672399896891406   acc mean: 0.8697428957535221
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.40834053245868346   acc max: 0.8849797090754942
# loss mean : 0.5020261351439562   acc mean: 0.8570230041660056
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26876787093237386   acc max: 0.9079837664377061
# loss mean : 0.38612219383090696   acc mean: 0.8780920140540005
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.31261350821416334   acc max: 0.9106901204957045
# loss mean : 0.43399635808313014   acc mean: 0.8688497976093718
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.39211888944021905   acc max: 0.8795669870060416
# loss mean : 0.5097930451461362   acc mean: 0.8639242212415872
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3078309418545363   acc max: 0.8958051445035715
# loss mean : 0.4165998304491113   acc mean: 0.8696075766302737
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3231335902568936   acc max: 0.9039242206310226
# loss mean : 0.43749068954639414   acc mean: 0.8774289599702227
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4653244772283247   acc max: 0.8728010768980715
# loss mean : 0.5321330071269901   acc mean: 0.8631799733332269
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3084438816217028   acc max: 0.9066305886424766
# loss mean : 0.4146052895802929   acc mean: 0.8759539926060157
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3261058704778855   acc max: 0.8958051488589853
# loss mean : 0.4811383397459823   acc mean: 0.8551691469888888
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43564083043067475   acc max: 0.8822733469519144
# loss mean : 0.5425700854283224   acc mean: 0.8460893118837205
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3101401182650229   acc max: 0.8985115088048581
# loss mean : 0.4075271201045007   acc mean: 0.8706224621160914
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30195880577431966   acc max: 0.907983768615413
# loss mean : 0.38927544153470633   acc mean: 0.878173205667807
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.40218362792902934   acc max: 0.8768606270601688
# loss mean : 0.5333396558578509   acc mean: 0.8354803778850177
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2834807288743485   acc max: 0.9106901161402907
# loss mean : 0.4084567372188356   acc mean: 0.8764817313251055
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3238080846440647   acc max: 0.898511500739277
# loss mean : 0.43486010683405546   acc mean: 0.8733829512563059
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.35447508229777036   acc max: 0.8863328890484306
# loss mean : 0.44272480133583153   acc mean: 0.8628010832295527
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36421484029341455   acc max: 0.8998646887777946
# loss mean : 0.4790590608224817   acc mean: 0.8679161024960679
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.40480536609605783   acc max: 0.8876860690213669
# loss mean : 0.48402723412471793   acc mean: 0.8631258447058954
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4446600121880739   acc max: 0.8768606168168808
# loss mean : 0.5368896965156228   acc mean: 0.8494857886865111
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36721747690189194   acc max: 0.883626522569437
# loss mean : 0.5416932048744375   acc mean: 0.8236941809827243
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.34633190782692824   acc max: 0.8890392387510152
# loss mean : 0.4593507317966795   acc mean: 0.8610554787125412
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.49836870072175105   acc max: 0.8741542649365891
# loss mean : 0.6335492672431453   acc mean: 0.8040460057219891
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3264796703206993   acc max: 0.9012178606851498
# loss mean : 0.4963211848384151   acc mean: 0.8688092021319475
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.37109132133252887   acc max: 0.8944519688860489
# loss mean : 0.4814805349614849   acc mean: 0.859404604605554
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.44478185771282697   acc max: 0.8660351850989707
# loss mean : 0.5706507122778763   acc mean: 0.8220162361767523
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3124573494487912   acc max: 0.8971583185886337
# loss mean : 0.4516041133638486   acc mean: 0.8636806484246285
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3718719572756384   acc max: 0.8903924289672397
# loss mean : 0.46692854133728234   acc mean: 0.866941814969454
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.42464871424299455   acc max: 0.8741542568710079
# loss mean : 0.5476651862699221   acc mean: 0.8390527749138207
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3073340361189294   acc max: 0.9039242265188968
# loss mean : 0.45450462184715335   acc mean: 0.8543166440432951
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3918228586165282   acc max: 0.8809201567356899
# loss mean : 0.5334251905419185   acc mean: 0.8357916092537896
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.413780347581484   acc max: 0.8782137967898171
# loss mean : 0.5123291859325118   acc mean: 0.8561840306155901
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3222793660079997   acc max: 0.8958051466812784
# loss mean : 0.4777264065203711   acc mean: 0.8444925586687697
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.33144736467420816   acc max: 0.8903924289672397
# loss mean : 0.46219163773629274   acc mean: 0.8501353209436506
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3916631763213704   acc max: 0.8822733469519144
# loss mean : 0.5079372787257815   acc mean: 0.8433423545492843
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2835963634580011   acc max: 0.9174560203603865
# loss mean : 0.4015930953811405   acc mean: 0.8835047371792375
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.28689877908671824   acc max: 0.9039242286966037
# loss mean : 0.4462218508499401   acc mean: 0.8636806522553766
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.39986223329226606   acc max: 0.8768606189945877
# loss mean : 0.505162532753809   acc mean: 0.8443166415968024
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29055526550148436   acc max: 0.9093369464106424
# loss mean : 0.3734994909655257   acc mean: 0.8817591337696302
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.28553271075869446   acc max: 0.9025710406580861
# loss mean : 0.3803390782877944   acc mean: 0.882192151362583
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3939714783422034   acc max: 0.8755074470872324
# loss mean : 0.4927144019836019   acc mean: 0.8614614355031788
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3070829679259428   acc max: 0.8985114963838632
# loss mean : 0.44337408916432425   acc mean: 0.8633423537023981
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3270242547311383   acc max: 0.8971583288319217
# loss mean : 0.46397933777920775   acc mean: 0.845642757653303
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.39984688134574115   acc max: 0.8755074470872324
# loss mean : 0.5137801711646403   acc mean: 0.8442219199637435
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29666981601102105   acc max: 0.9106901183179976
# loss mean : 0.38897511266000534   acc mean: 0.8804600813577558
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2981091130408931   acc max: 0.8944519688860489
# loss mean : 0.43675214025220943   acc mean: 0.8678890412069947
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3820379757913427   acc max: 0.8768606189945877
# loss mean : 0.4927680265165472   acc mean: 0.8511366729734714
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2669769453744282   acc max: 0.9093369383450612
# loss mean : 0.3652142653260406   acc mean: 0.8768200276733574
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
