# %%
def featureExtraction(fileDir, minCount, maxCount, leftLight):
    userHp1 = []
    userLp1 = []
    userLhpl1 = []
    userLlpl1 = []
    userHpl1 = []
    userLpl1 = []
    userLhpg1 = []
    userLlpg1 = []
    userRhpg1 = []
    userRlpg1 = []
    userBlink1 = []
    userNotBlink1 = []
    
    for count in range(minCount, maxCount):
        file = open(fileDir + '/file' + str(count) + '-' + str(leftLight) + '.txt', 'r')
        x = file.read()
        file.close()
    
        x = x.split(',')
    
        data1 = []
    
        for index, item in enumerate(x):
            data1.append(float(item))
        
        for index, item in enumerate(x):
            if(index != len(data1) -1):
                data1[index] = data1[index + 1]
            
        temp = 0
        index = 0

        start1 = []
        middle1 = []
        finish1 = []

        for i in range(0, len(data1)):
            if((temp + 150 < i) and (data1[i] > 100)):
                for j in range(i, 0, -1):
                    if(data1[j] <= 0):
                        start1.append(j)
                        break
                
                for j in range(start1[index] + 1, len(data1)):
                    if(data1[j] <= 0):
                        middle1.append(j)
                        break
                
                for j in range(middle1[index] + 1, len(data1)):
                    if(data1[j] >= 0):
                        finish1.append(j)
                        break
                
                i = finish1[index]
                index = index + 1
                temp = i
   
        temp = 0
    
        hp1 = []
        lp1 = []
        lhpl1 = []
        llpl1 = []
        hpl1 = []
        lpl1 = []
        lhpg1 = []
        llpg1 = []
        rhpg1 = []
        rlpg1 = []
        blink1 = []
        notBlink1 = []
    
        index = 0;
    
        for i in range(start1[0], finish1[len(finish1) - 1]):
            hp1.append(0)
            lp1.append(0)
            lhpl1.append(0)
            llpl1.append(0)
            hpl1.append(0)
            lpl1.append(0)
            lhpg1.append(0)
            llpg1.append(0)
            rhpg1.append(0)
            rlpg1.append(0)
            blink1.append(0)
            notBlink1.append(0)
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] < data1[j]):
                    hp1[index] = data1[j]
                    lhpl1[index] = j - start1[index]
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] > data1[j]):
                    lp1[index] = data1[j]
                    llpl1[index] = j - start1[index]
            
            hpl1[index] = middle1[index] - start1[index]
            lpl1[index] = finish1[index] - middle1[index]
    
            lhpg1[index] = hp1[index] / lhpl1[index]
            llpg1[index] = lp1[index] / llpl1[index]
            rhpg1[index] = hp1[index] / (hpl1[index] - lhpg1[index])
            rlpg1[index] = lp1[index] / (lpl1[index] - llpl1[index])
    
            index = index + 1
    
            if(len(start1) == index):
                break
    
            i = start1[index]
        
        index = 0;
        
        for i in range(0, len(finish1)):
            blink1[i] = finish1[i] - start1[i]

        for i in range(0, len(finish1) - 1):
            notBlink1[i] = start1[i + 1] - finish1[i]
        
        for i in range(0, len(finish1)):
            userHp1.append(hp1[i])
            userLp1.append(lp1[i])
            userLhpl1.append(lhpl1[i])
            userLlpl1.append(llpl1[i])
            userHpl1.append(hpl1[i])
            userLpl1.append(lpl1[i])
            userLhpg1.append(lhpg1[i])
            userLlpg1.append(llpg1[i])
            userRhpg1.append(rhpg1[i])
            userRlpg1.append(rlpg1[i])
            userBlink1.append(blink1[i])
            userNotBlink1.append(notBlink1[i])
            
    return userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1

# %%
user1Data  = []
user1Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user1', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user1', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user1Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user1Label.append(0)

# %%
user2Data  = []
user2Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user2', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user2', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user2Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user2Label.append(1)

# %%
user3Data  = []
user3Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user3Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user3Label.append(2)

# %%
import numpy as np

# %%
user1Data = np.array(user1Data)
user2Data = np.array(user2Data)
user3Data = np.array(user3Data)

user1Label = np.array(user1Label)
user2Label = np.array(user2Label)
user3Label = np.array(user3Label)

# %%
data = np.concatenate((user1Data, user2Data, user3Data), axis=0)

# %%
len(data)
# Out:
# 3239

# %%
label = np.concatenate((user1Label, user2Label, user3Label), axis=0)

# %%
len(label)
# Out:
# 3239

# %%
s = np.arange(data.shape[0])
np.random.shuffle(s)

# %%
data = data[s]
label = label[s]

# %%
label
# Out:
# array([0, 1, 1, ..., 2, 1, 1])

# %%
tempLabel = []

# %%
for i in range(0, len(label)):
    if(label[i] == 0):
        tempLabel.append([1, 0, 0])
    elif(label[i] == 1):
        tempLabel.append([0, 1, 0])
    else:
        tempLabel.append([0, 0, 1])

# %%
label = tempLabel

# %%
label = np.array(label)

# %%
train_data = data[:2500]
val_data = data[2500:]

train_label = label[:2500]
val_label = label[2500:]

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

val_data -= mean
val_data /= std

# %%
from keras import models
from keras import layers
from keras import regularizers
from keras import optimizers
# Out:
# Using TensorFlow backend.
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:496: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:497: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\HongGi-hyeon\anaconda3\envs\test_tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:502: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def build_model(actiFunc, lossFunc, hidden, node, dropout):
    model = models.Sequential()
    
    model.add(layers.Dense(node[0], activation=actiFunc, input_shape=(12, )))
    model.add(layers.Dropout(dropout))
    
    if(hidden == 2):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    if(hidden == 3):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
        model.add(layers.Dense(node[2], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='rmsprop', loss=lossFunc, metrics=['accuracy'])
    return model

# %%
import numpy as np

num_epochs = 100


actiFunc = ['relu']
lossFunc = ['categorical_crossentropy']
hidden = [3, 2, 1]
#node = [[4, 4], [4, 8], [4, 16], [4, 32], [8, 4], [8, 8], [8, 16], [8, 32], [16, 4], [16, 8], [16, 16], [16, 32], [32, 4], [32, 8], [32, 16], [32, 32]]
node = [
    [4, 4, 4], [4, 4, 8], [4, 4, 16], [4, 4, 32], [4, 8, 4], [4, 8, 8], [4, 8, 16], [4, 8, 32], [4, 16, 4], [4, 16, 8], [4, 16, 16], [4, 16, 32], [4, 32, 4], [4, 32, 8], [4, 32, 16], [4, 32, 32],
    [8, 4, 4], [8, 4, 8], [8, 4, 16], [8, 4, 32], [8, 8, 4], [8, 8, 8], [8, 8, 16], [8, 8, 32], [8, 16, 4], [8, 16, 8], [8, 16, 16], [8, 16, 32], [8, 32, 4], [8, 32, 8], [8, 32, 16], [8, 32, 32],
    [16, 4, 4], [16, 4, 8], [16, 4, 16], [16, 4, 32], [16, 8, 4], [16, 8, 8], [16, 8, 16], [16, 8, 32], [16, 16, 4], [16, 16, 8], [16, 16, 16], [16, 16, 32], [16, 32, 4], [16, 32, 8], [16, 32, 16], [16, 32, 32],
    [32, 4, 4], [32, 4, 8], [32, 4, 16], [32, 4, 32], [32, 8, 4], [32, 8, 8], [32, 8, 16], [32, 8, 32], [32, 16, 4], [32, 16, 8], [32, 16, 16], [32, 16, 32], [32, 32, 4], [32, 32, 8], [32, 32, 16], [32, 32, 32]
]
batchSize = [128, 256, 512]
dropout = [0, 0.1, 0.3, 0.5]

all_acc_histories = []
all_loss_histories = []

for i in range(len(actiFunc)):
    for j in range(len(lossFunc)):
        for k in range(len(hidden)):
            for l in range(len(node)):
                for m in range(len(batchSize)):
                    for n in range(len(dropout)):
                        print('Activation:', actiFunc[i] , '  Loss:', lossFunc[j] , '  HiddenLayer:', hidden[k] , '  Node:[', node[l][0], ',', node[l][1] , ',', node[l][2], ']  BatchSize:', batchSize[m], '  Dropout:', dropout[n])
    
                        model = build_model(actiFunc[i], lossFunc[j], hidden[k], node[l], dropout[n])
                        history = model.fit(train_data, train_label, validation_data=(val_data, val_label), epochs=num_epochs, batch_size=batchSize[m], verbose=False)
    
                        acc_history = history.history['val_acc']
                        all_acc_histories.append(acc_history)
                        loss_history = history.history['val_loss']
                        all_loss_histories.append(loss_history)
    
                        print('loss min :', min(loss_history), '  acc max:', max(acc_history))
                        print('loss mean :', np.mean(loss_history), '  acc mean:', np.mean(acc_history))
    
                        print()
# Out:
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.3357923048194271   acc max: 0.8971583256863451
# loss mean : 0.4795722178253818   acc mean: 0.8724627888299454
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.3850949120698988   acc max: 0.8985115029169839
# loss mean : 0.5401415922757898   acc mean: 0.8376995928841611
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.7561631643078486   acc max: 0.7983761871780529
# loss mean : 0.8368512302451593   acc mean: 0.6971583221991909
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7449679035133857   acc max: 0.836265220048463
# loss mean : 0.8703747270620239   acc mean: 0.6997970232020695
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.38936550715618107   acc max: 0.898511500739277
# loss mean : 0.6724955815560765   acc mean: 0.7653585924996572
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.40927903707037117   acc max: 0.9012178628628567
# loss mean : 0.665662616613108   acc mean: 0.7586197569682004
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.6063105071187825   acc max: 0.8998646909555015
# loss mean : 0.8112386562367736   acc mean: 0.7088497995055899
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.9062970234673465   acc max: 0.657645465395286
# loss mean : 0.9926095928334416   acc mean: 0.5632476316757389
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5822120365335106   acc max: 0.7902571075017462
# loss mean : 0.7966342810929546   acc mean: 0.6914073042408216
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.741589996263042   acc max: 0.7185385691780845
# loss mean : 0.9030089404174859   acc mean: 0.6095128575644894
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.8077705408949329   acc max: 0.717185389205148
# loss mean : 0.9262156479365125   acc mean: 0.5516914779439831
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.8349738335577174   acc max: 0.7401894509227738
# loss mean : 0.8994588222764986   acc mean: 0.67715832193464
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2602593502349879   acc max: 0.906630584125751
# loss mean : 0.37410974267895397   acc mean: 0.8681732088529048
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.37980474440912754   acc max: 0.8971583215728987
# loss mean : 0.48222304490123946   acc mean: 0.8739512863654406
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.46785941913582796   acc max: 0.8890392431064291
# loss mean : 0.5810910033413458   acc mean: 0.867104195396697
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.8425627956532336   acc max: 0.6847090662251628
# loss mean : 0.9345213734571278   acc mean: 0.5812178613368487
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 256   Dropout: 0
# loss min : 0.4188018262950913   acc max: 0.8903924289672397
# loss mean : 0.6518958250353559   acc mean: 0.7835453309394993
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.38212063827921156   acc max: 0.8971583310096286
# loss mean : 0.6122654125356546   acc mean: 0.8271583247019412
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.5081177730924867   acc max: 0.8836265269248508
# loss mean : 0.6216883828953734   acc mean: 0.849161026906903
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.8731259689924682   acc max: 0.6332882317703051
# loss mean : 0.9583360115423579   acc mean: 0.5230987837854193
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4074744487808909   acc max: 0.8998646887777946
# loss mean : 0.6394227829599736   acc mean: 0.7975913394618582
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48879533126970426   acc max: 0.8903924289672397
# loss mean : 0.7675066572113189   acc mean: 0.7764005431976468
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7120400819630036   acc max: 0.8430311168482242
# loss mean : 0.8561521301032404   acc mean: 0.8165764536618865
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.9048536307756891   acc max: 0.6481732114726055
# loss mean : 1.0117158602006702   acc mean: 0.5245602158300771
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 128   Dropout: 0
# loss min : 0.27963582770104983   acc max: 0.9120432987748689
# loss mean : 0.39680611664653626   acc mean: 0.8703788897528214
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.34627162910120735   acc max: 0.8930987857675359
# loss mean : 0.4723797156842216   acc mean: 0.8497699607749429
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.541187551008671   acc max: 0.8863328831605563
# loss mean : 0.7431912532388277   acc mean: 0.7311907990754699
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.690792705515886   acc max: 0.8592692823306795
# loss mean : 0.8204159178003084   acc mean: 0.7076048713148205
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2996846440277177   acc max: 0.9120432945807667
# loss mean : 0.48153143307877166   acc mean: 0.8292963497483844
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.33308358149696266   acc max: 0.8971583288319217
# loss mean : 0.5310682301830213   acc mean: 0.8336265254335247
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.5464525433693268   acc max: 0.874154254693301
# loss mean : 0.7629634019603425   acc mean: 0.7589986469047157
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.7738685447405091   acc max: 0.6833558935919053
# loss mean : 0.8680832072241542   acc mean: 0.6400947258078037
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3874937002326542   acc max: 0.8917455986968881
# loss mean : 0.6975567809586113   acc mean: 0.7873207026776506
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.36958389449990653   acc max: 0.8903924267895328
# loss mean : 0.6262788544734372   acc mean: 0.8150744247769228
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5865886235592007   acc max: 0.859269291122163
# loss mean : 0.7636051892540614   acc mean: 0.725345061931139
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.8447783950701134   acc max: 0.6698240857969602
# loss mean : 0.9844717362365799   acc mean: 0.5348579187164932
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2766870450989642   acc max: 0.9012178642340055
# loss mean : 0.44141801742723424   acc mean: 0.8428146153519053
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2836793788553736   acc max: 0.9120432987748689
# loss mean : 0.3827519348640807   acc mean: 0.8845602158595165
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.6698352888085362   acc max: 0.71583220310237
# loss mean : 0.727713337132508   acc mean: 0.6961299032602003
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.6887627622271423   acc max: 0.8159675229547472
# loss mean : 0.7682770748632041   acc mean: 0.7134100143802989
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.34107674765167445   acc max: 0.8795669767627535
# loss mean : 0.484284525770941   acc mean: 0.8351826790624445
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3502802250349796   acc max: 0.8903924289672397
# loss mean : 0.5443670135252531   acc mean: 0.8087956704503791
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.4485156543764597   acc max: 0.8958051488589853
# loss mean : 0.6011388544070865   acc mean: 0.8245872822932202
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.6779363189240432   acc max: 0.8714479012805489
# loss mean : 0.773721698385453   acc mean: 0.7774695548749905
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36674314866369245   acc max: 0.8890392468165964
# loss mean : 0.6084430769323819   acc mean: 0.7938971583611749
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.41073136259480325   acc max: 0.8917455986968881
# loss mean : 0.6505854305120863   acc mean: 0.7961840339341731
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5069296002307345   acc max: 0.884979701009913
# loss mean : 0.7325697078320911   acc mean: 0.7744519612068089
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7746142820834468   acc max: 0.6765899915495164
# loss mean : 0.8770891494308983   acc mean: 0.6314614349978703
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.30016925777730824   acc max: 0.910690125415709
# loss mean : 0.46286175391146545   acc mean: 0.84894452073416
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.3966647967676026   acc max: 0.891745599180823
# loss mean : 0.5571009144267629   acc mean: 0.8247902568864239
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.692013203129878   acc max: 0.7117726684261885
# loss mean : 0.7574172221646418   acc mean: 0.7017456041145388
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7720505713771257   acc max: 0.6955345073798028
# loss mean : 0.8623409809101581   acc mean: 0.6605142090268967
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.38767621025987503   acc max: 0.8944519608204677
# loss mean : 0.6777815260418535   acc mean: 0.8050879579020288
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.39858577957979235   acc max: 0.8998646909555015
# loss mean : 0.6062059889634986   acc mean: 0.7856427641956989
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.6882921715389246   acc max: 0.714479021193694
# loss mean : 0.7989685777745161   acc mean: 0.6958186714042669
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.7970893065242225   acc max: 0.7090663093675296
# loss mean : 0.8974553425402378   acc mean: 0.6394722591019935
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.38563495459027475   acc max: 0.8930987786698245
# loss mean : 0.6676762610105281   acc mean: 0.7706765914306105
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5761740652892199   acc max: 0.8809201648012711
# loss mean : 0.7453718203104558   acc mean: 0.7475372126025017
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6289431460816741   acc max: 0.867388354828619
# loss mean : 0.8509884496180387   acc mean: 0.7021244915606043
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.957316983213928   acc max: 0.4749661749770741
# loss mean : 1.0307446982065298   acc mean: 0.46185386042915916
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 128   Dropout: 0
# loss min : 0.28052236597496055   acc max: 0.9093369388289961
# loss mean : 0.38085370717476935   acc mean: 0.8657645475263525
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.3652435902087711   acc max: 0.9052774055239635
# loss mean : 0.5540896648095973   acc mean: 0.818403248644972
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.6896162840445729   acc max: 0.7131258417853483
# loss mean : 0.7457253935057997   acc mean: 0.7012043269859762
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.6229492694502432   acc max: 0.8660351835665103
# loss mean : 0.7711879828584373   acc mean: 0.7541001346162917
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 256   Dropout: 0
# loss min : 0.345181578067062   acc max: 0.905277410847247
# loss mean : 0.5140417525547283   acc mean: 0.8600270663595004
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3507351731334552   acc max: 0.901217868750731
# loss mean : 0.5330403682779072   acc mean: 0.8402977037841155
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.561457005905363   acc max: 0.8890392387510152
# loss mean : 0.6508664648023124   acc mean: 0.8214073074872179
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.7550663593173511   acc max: 0.6968876852556881
# loss mean : 0.8489112627764357   acc mean: 0.6677943176039177
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3584495383605905   acc max: 0.8876860587780788
# loss mean : 0.6139745121895863   acc mean: 0.8414479033227543
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3927849564645868   acc max: 0.9012178709284379
# loss mean : 0.7065389730473816   acc mean: 0.7727740194131297
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7008410251834234   acc max: 0.710419489340466
# loss mean : 0.8288486806449451   acc mean: 0.6931799722177574
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7688621163206913   acc max: 0.6955345074604586
# loss mean : 0.8778731288638909   acc mean: 0.6671583227762831
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2525400704879399   acc max: 0.9079837654698363
# loss mean : 0.3693936155627561   acc mean: 0.8812719898585215
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2796085681942706   acc max: 0.9093369388289961
# loss mean : 0.4035717084626787   acc mean: 0.8692422208355307
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.40224005465417173   acc max: 0.8876860631334926
# loss mean : 0.5472097349380608   acc mean: 0.8261975636832285
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7264219893492929   acc max: 0.7117726618124119
# loss mean : 0.8069981747607581   acc mean: 0.6653721227084511
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 256   Dropout: 0
# loss min : 0.306591841743828   acc max: 0.9066305886424766
# loss mean : 0.5341896102957538   acc mean: 0.81300406089413
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.35364215606281657   acc max: 0.8998646807122134
# loss mean : 0.49892222893334853   acc mean: 0.8363058184367554
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.6214720047859119   acc max: 0.7077131315723001
# loss mean : 0.7313048753412555   acc mean: 0.6983897171872232
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.6847904752007357   acc max: 0.8484438389176767
# loss mean : 0.8306286981552637   acc mean: 0.7163193509930366
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.38450641863562257   acc max: 0.8822733367086263
# loss mean : 0.682809197046518   acc mean: 0.741244925643457
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.37787286499679007   acc max: 0.8958051510366922
# loss mean : 0.570664548456911   acc mean: 0.8228010844756851
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5806909324513075   acc max: 0.8795669870060416
# loss mean : 0.8534255462239657   acc mean: 0.7091474978756841
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.6763605485910976   acc max: 0.8416779390529947
# loss mean : 0.8325329000870818   acc mean: 0.673531800712155
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.27095841403662435   acc max: 0.9147496614630394
# loss mean : 0.35827727308353174   acc mean: 0.8839783496317911
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2875224186135242   acc max: 0.9093369388289961
# loss mean : 0.3955978525507596   acc mean: 0.8870365367053489
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.44535653775051254   acc max: 0.8809201605265131
# loss mean : 0.5522664730591605   acc mean: 0.8370094709273763
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.6741281106604291   acc max: 0.8633288208783398
# loss mean : 0.8123342802108382   acc mean: 0.6809201609943168
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.28366334681904526   acc max: 0.9106901248511184
# loss mean : 0.4365767650340503   acc mean: 0.8684438428181919
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.2910113524196919   acc max: 0.9079837627275387
# loss mean : 0.4405869550535176   acc mean: 0.8633558902229119
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.5329012078345226   acc max: 0.8890392365733083
# loss mean : 0.6881286447800704   acc mean: 0.7601894442654431
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.765608778180547   acc max: 0.6982408674063315
# loss mean : 0.8447218581868766   acc mean: 0.6607171845807113
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.31697833860678665   acc max: 0.8985115029169839
# loss mean : 0.5690052603445293   acc mean: 0.8165087953125191
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.36078832993165405   acc max: 0.905277410847247
# loss mean : 0.570143240335749   acc mean: 0.8188903949128435
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43739979882524205   acc max: 0.8930987830252383
# loss mean : 0.6303718602951711   acc mean: 0.8112990535354098
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7002797004173186   acc max: 0.7266576453055354
# loss mean : 0.8047661613474356   acc mean: 0.6998782142246691
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.29831596293533286   acc max: 0.9093369402001449
# loss mean : 0.4871279215223895   acc mean: 0.8413396484962335
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.3716471996939715   acc max: 0.9052774055239635
# loss mean : 0.5214076409030186   acc mean: 0.8544654942107297
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.420056014406181   acc max: 0.8944519657404723
# loss mean : 0.5713081040325121   acc mean: 0.827334237100307
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7207236781978478   acc max: 0.7023004086156337
# loss mean : 0.8218574840314332   acc mean: 0.6358863330238242
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.29679246676306925   acc max: 0.9025710487236673
# loss mean : 0.5010544355215659   acc mean: 0.832652235179938
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3695373956986145   acc max: 0.8985115109825651
# loss mean : 0.5947555738703646   acc mean: 0.8315967555491303
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.5890472407915273   acc max: 0.8863328788051424
# loss mean : 0.8103368958512243   acc mean: 0.7041542637348175
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.7414421977951658   acc max: 0.6982408674063315
# loss mean : 0.8819186564388715   acc mean: 0.5962246283957375
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4473601155416569   acc max: 0.8890392387510152
# loss mean : 0.662445898103617   acc mean: 0.7825304459517313
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4953242250401854   acc max: 0.8822733469519144
# loss mean : 0.7695961426454564   acc mean: 0.7623410030306192
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6429678403314945   acc max: 0.8755074368439444
# loss mean : 0.8201822591949056   acc mean: 0.6618267921226273
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7308111711025883   acc max: 0.8484438389176767
# loss mean : 0.8841052033606013   acc mean: 0.7102571046118484
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2835629132748941   acc max: 0.9120433040174967
# loss mean : 0.41682012564133397   acc mean: 0.8636129915520688
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.30032392263573787   acc max: 0.9079837654698363
# loss mean : 0.4126145463282589   acc mean: 0.8792692834675231
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.40555958193758346   acc max: 0.8998646856322179
# loss mean : 0.5106247698413826   acc mean: 0.8676995956865474
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.6234880493038885   acc max: 0.8849797031876199
# loss mean : 0.7476712270179846   acc mean: 0.785602165242816
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 256   Dropout: 0
# loss min : 0.32292808005548457   acc max: 0.8917455986968881
# loss mean : 0.5669479463444028   acc mean: 0.8074289570218494
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3726216740956648   acc max: 0.9039242308743106
# loss mean : 0.5908593345208645   acc mean: 0.8106495263950751
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.5019917662717976   acc max: 0.8890392468165964
# loss mean : 0.678482486319316   acc mean: 0.7869688784862402
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.6412945325222971   acc max: 0.8606224652072251
# loss mean : 0.7957467434032037   acc mean: 0.7446549396069674
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.32548277900731937   acc max: 0.8930987889131126
# loss mean : 0.5335055877318723   acc mean: 0.8627063587860421
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3675039162574505   acc max: 0.905277410847247
# loss mean : 0.6138871363390122   acc mean: 0.7994587287036587
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5336067464419405   acc max: 0.8849796944767923
# loss mean : 0.7338041827110865   acc mean: 0.734857914676847
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7803495081093702   acc max: 0.66035183340674
# loss mean : 0.9360129087211638   acc mean: 0.5594046028633887
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2566793828759045   acc max: 0.9147496639633695
# loss mean : 0.37456811533285567   acc mean: 0.8858186756540216
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2806488417280543   acc max: 0.9052773989101869
# loss mean : 0.3882915373009419   acc mean: 0.8794181317163577
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.3651642073071858   acc max: 0.8998646842610691
# loss mean : 0.5001188603116147   acc mean: 0.8681596758393055
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.5115144790751363   acc max: 0.8903924244505143
# loss mean : 0.6207857523695219   acc mean: 0.8423139379303577
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2761046060528581   acc max: 0.9106901248511184
# loss mean : 0.40903877935386146   acc mean: 0.8857239528962175
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.28526721924986986   acc max: 0.9079837627275387
# loss mean : 0.4569697454202724   acc mean: 0.8652097423828341
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.6590767254364829   acc max: 0.7144790314369821
# loss mean : 0.7302130599555854   acc mean: 0.7045872806720384
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.5812171290304728   acc max: 0.8294993149411534
# loss mean : 0.825582640688055   acc mean: 0.6267658987746186
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3375227455760533   acc max: 0.8998646909555015
# loss mean : 0.540401464127236   acc mean: 0.8256292294568718
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3386048107976359   acc max: 0.8890392409287222
# loss mean : 0.5188902716945569   acc mean: 0.8373071723458569
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6278501930514272   acc max: 0.7415426315409566
# loss mean : 0.7547587742107003   acc mean: 0.6841136670955463
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.736625667837863   acc max: 0.710419479097178
# loss mean : 0.8734943612317112   acc mean: 0.6443437080176015
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2596843349917493   acc max: 0.9120433015171665
# loss mean : 0.3717777483211641   acc mean: 0.8816508796867565
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.26820027344281683   acc max: 0.9066305854968999
# loss mean : 0.3896193737610267   acc mean: 0.8737077159520252
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.3556507265696829   acc max: 0.8944519643693235
# loss mean : 0.4808297727600809   acc mean: 0.8411637364406548
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.4824794117104217   acc max: 0.8768606206077039
# loss mean : 0.5770231294168188   acc mean: 0.8465087943236784
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.27591735213309404   acc max: 0.9079837707931199
# loss mean : 0.39594391690942676   acc mean: 0.8718944551496286
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3093003509654405   acc max: 0.9066305908201835
# loss mean : 0.47799490594412225   acc mean: 0.8554533183889232
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.40036206981809924   acc max: 0.9039242308743106
# loss mean : 0.5790913424311214   acc mean: 0.8131664434748831
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.5421416818772988   acc max: 0.8930987910908195
# loss mean : 0.6587842043435783   acc mean: 0.836265224522441
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36460097253080637   acc max: 0.8971583185886337
# loss mean : 0.573542178186496   acc mean: 0.8272395123942619
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30626426002008184   acc max: 0.8944519710637558
# loss mean : 0.4603027770618866   acc mean: 0.8809336988593632
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4729519508607655   acc max: 0.8863328868707236
# loss mean : 0.6512053265002165   acc mean: 0.8039648152655934
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.5874554153546913   acc max: 0.8525033810141929
# loss mean : 0.7338075248774076   acc mean: 0.7905412712068134
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.25897397800614613   acc max: 0.9052774041528147
# loss mean : 0.36677544025227904   acc mean: 0.8756562927191892
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.30968824274969037   acc max: 0.9093369440716239
# loss mean : 0.42677041724223413   acc mean: 0.8748443847717227
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.3982050761640959   acc max: 0.9012178656051543
# loss mean : 0.5362603303705403   acc mean: 0.8546008140082612
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7321222753582852   acc max: 0.6995940486697608
# loss mean : 0.8512822077948604   acc mean: 0.6069147504993155
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.26808814151925875   acc max: 0.9188092025110299
# loss mean : 0.5029506690534027   acc mean: 0.8480108277884806
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.3221398068942301   acc max: 0.8971583185886337
# loss mean : 0.5038971854526555   acc mean: 0.841935048650179
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.535767363598608   acc max: 0.8863328868707236
# loss mean : 0.6541028996709235   acc mean: 0.8089986456678586
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.7357532678018243   acc max: 0.8227334209643455
# loss mean : 0.8200847720131985   acc mean: 0.7469553458638218
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4351981523798348   acc max: 0.8958051429711111
# loss mean : 0.6980871756505904   acc mean: 0.771907985265668
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.36570414428943226   acc max: 0.9025710406580861
# loss mean : 0.616102797589057   acc mean: 0.7790392422801102
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5166613070826085   acc max: 0.901217868750731
# loss mean : 0.7256994296281686   acc mean: 0.7819891754542863
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.7387908373698492   acc max: 0.7144790190159871
# loss mean : 0.8591294110426237   acc mean: 0.6625845718476545
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 128   Dropout: 0
# loss min : 0.2582156616634864   acc max: 0.9201623827259338
# loss mean : 0.3574508231331837   acc mean: 0.8871447909821998
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2717548409963332   acc max: 0.9025710442069419
# loss mean : 0.3668720146396647   acc mean: 0.8793504737702694
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.35380437345078897   acc max: 0.8971583256863451
# loss mean : 0.46402544045077293   acc mean: 0.8667253064141385
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.4983571511724805   acc max: 0.8890392417352803
# loss mean : 0.6273892875542015   acc mean: 0.821393773950969
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 256   Dropout: 0
# loss min : 0.24718084229668036   acc max: 0.9120433026463479
# loss mean : 0.3816926993320775   acc mean: 0.8789174589813159
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.28492457757380074   acc max: 0.9106901307389926
# loss mean : 0.41835866135475763   acc mean: 0.8783085256782696
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.41424443737095845   acc max: 0.8998646909555015
# loss mean : 0.5710571792673355   acc mean: 0.8402300408789044
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.6431819290043698   acc max: 0.8200270653738866
# loss mean : 0.75920746449366   acc mean: 0.7255886341984281
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3203437119036792   acc max: 0.9012178709284379
# loss mean : 0.5447535357746284   acc mean: 0.8179566996136279
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4236404481211599   acc max: 0.8985115088048581
# loss mean : 0.616857034630156   acc mean: 0.776102840351155
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4465225891831441   acc max: 0.8958051386156972
# loss mean : 0.645680561359261   acc mean: 0.8216508787682884
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.6396339913182394   acc max: 0.732070367374988
# loss mean : 0.765412774833678   acc mean: 0.6962246286502066
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 128   Dropout: 0
# loss min : 0.26349932862715403   acc max: 0.9120433015171665
# loss mean : 0.369107413914594   acc mean: 0.882178619480585
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2917062993664219   acc max: 0.9093369388289961
# loss mean : 0.3826188237973172   acc mean: 0.8887550749741646
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.3386707762420097   acc max: 0.8958051429711111
# loss mean : 0.48043528162094185   acc mean: 0.8464682006997251
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7442965268766122   acc max: 0.7144790217582847
# loss mean : 0.8133441329647627   acc mean: 0.6608660338349207
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2739913327485847   acc max: 0.912043310711929
# loss mean : 0.40808409397592404   acc mean: 0.8811502040888364
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.2652551957856012   acc max: 0.9133964906848655
# loss mean : 0.3911498425582345   acc mean: 0.868876863528895
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.35629337816341644   acc max: 0.8944519608204677
# loss mean : 0.4454444267035176   acc mean: 0.8840866023705354
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.5636010130461563   acc max: 0.8876860587780788
# loss mean : 0.7391012458904508   acc mean: 0.7796752368375476
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36457758645888755   acc max: 0.9012178606851498
# loss mean : 0.5888125072776544   acc mean: 0.8062652229335214
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30926949596372766   acc max: 0.9079837583721249
# loss mean : 0.48781401785647593   acc mean: 0.8732476305989839
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.36648604721435835   acc max: 0.8903924311449466
# loss mean : 0.5717383116334475   acc mean: 0.8457645461862561
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.6238525167853648   acc max: 0.8525033810141929
# loss mean : 0.7923333648875538   acc mean: 0.7454533149320152
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.25938427317207013   acc max: 0.9147496628341881
# loss mean : 0.3387027614502203   acc mean: 0.8924086599308034
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2422388055247125   acc max: 0.9133964801189541
# loss mean : 0.3343779404620678   acc mean: 0.881488497506459
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.3370836729206477   acc max: 0.8998646842610691
# loss mean : 0.42182173891262686   acc mean: 0.8869282815614477
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.5677464406771008   acc max: 0.8673883607971491
# loss mean : 0.6700513805152599   acc mean: 0.8012584584483596
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2494351935846396   acc max: 0.9161028506307383
# loss mean : 0.36906620401712653   acc mean: 0.8947361314570954
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.2906984288815071   acc max: 0.9066305908201835
# loss mean : 0.4048383420891304   acc mean: 0.8693504731234099
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.3340318237251132   acc max: 0.9066305805768954
# loss mean : 0.4791548134626491   acc mean: 0.867023004349901
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.49926568815769456   acc max: 0.8958051510366922
# loss mean : 0.6377443437780353   acc mean: 0.8424763214572034
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29529773733290027   acc max: 0.8998646887777946
# loss mean : 0.45109831781364756   acc mean: 0.833951285257633
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30260159391834224   acc max: 0.9093369507660563
# loss mean : 0.4965285365426654   acc mean: 0.8391474978252742
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4222565587302506   acc max: 0.9012178606851498
# loss mean : 0.6251472480560832   acc mean: 0.8341677961011539
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.6539704288294254   acc max: 0.7604871372086108
# loss mean : 0.8013181729358653   acc mean: 0.668849796869355
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.26398639866883117   acc max: 0.9147496653345183
# loss mean : 0.41552132726280233   acc mean: 0.8771718539057631
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.35553298077983364   acc max: 0.9093369454427727
# loss mean : 0.49356817035858946   acc mean: 0.8550202991764019
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.598853594072778   acc max: 0.8863328804182586
# loss mean : 0.7722170138020316   acc mean: 0.7431393772928254
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.7435070790844454   acc max: 0.7063599485344428
# loss mean : 0.819346385298143   acc mean: 0.6748308540697187
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2818800684402373   acc max: 0.9106901146078303
# loss mean : 0.47764810482183717   acc mean: 0.8502300417003836
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.4448154302911281   acc max: 0.907983768615413
# ...
# loss min : 0.2460865346520776   acc max: 0.9133964804415774
# loss mean : 0.36823766345382547   acc mean: 0.8923815991042915
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.3210798551974987   acc max: 0.8971583310096286
# loss mean : 0.4988111466689587   acc mean: 0.8821650903158806
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2299956248238864   acc max: 0.9242219143371944
# loss mean : 0.3411282817232996   acc mean: 0.9015696884532418
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.24248105146404209   acc max: 0.916102834499576
# loss mean : 0.35983781766201867   acc mean: 0.8896346435140372
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.2742601315489641   acc max: 0.9106901146078303
# loss mean : 0.4355360272206134   acc mean: 0.8913531816570298
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.3309508817766936   acc max: 0.8985115088048581
# loss mean : 0.5671360822991848   acc mean: 0.8546414096002165
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.22452693861053502   acc max: 0.9323410024823613
# loss mean : 0.2776823668490404   acc mean: 0.9144248982622755
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.21221504770773836   acc max: 0.9323410011112125
# loss mean : 0.2790728853608662   acc mean: 0.911759134056765
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.2392623737272939   acc max: 0.9255751012465305
# loss mean : 0.3134024375987634   acc mean: 0.9067929644820173
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.27641238403255786   acc max: 0.9093369440716239
# loss mean : 0.4010715341733338   acc mean: 0.8722192159839508
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.21935362579535406   acc max: 0.9255750964878376
# loss mean : 0.3071261657423595   acc mean: 0.9034912053141768
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.22961607289088434   acc max: 0.9215155624569027
# loss mean : 0.3048268358036371   acc mean: 0.9014614376099088
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.25115471600437683   acc max: 0.9133964847969912
# loss mean : 0.34684058024934883   acc mean: 0.887672532758145
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.28260444138950197   acc max: 0.9133964745537031
# loss mean : 0.43479470253535146   acc mean: 0.8744654917144326
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.22526257127241128   acc max: 0.9282814564337104
# loss mean : 0.35609499607119255   acc mean: 0.905006765943419
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.24738235005425827   acc max: 0.9215155565690285
# loss mean : 0.3480799291017736   acc mean: 0.9014884986412862
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.2739950510419915   acc max: 0.9161028425651571
# loss mean : 0.40839932229203535   acc mean: 0.8944925594797636
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.30869864828693044   acc max: 0.9012178709284379
# loss mean : 0.5038440304377566   acc mean: 0.8833288250530845
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 128   Dropout: 0
# loss min : 0.25018718653183347   acc max: 0.9215155585854238
# loss mean : 0.36204653361834915   acc mean: 0.8895805127590046
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.2282633601369006   acc max: 0.9147496587207418
# loss mean : 0.2998909653106223   acc mean: 0.9016508784692567
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.31007418649445045   acc max: 0.9093369388289961
# loss mean : 0.43532964717954686   acc mean: 0.8600405946127939
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.3719261731443289   acc max: 0.9039242255510271
# loss mean : 0.5011503313814513   acc mean: 0.8699458731188665
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 256   Dropout: 0
# loss min : 0.22822753082915476   acc max: 0.9282814703871659
# loss mean : 0.3407931376798065   acc mean: 0.905304468563671
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.23694451994115187   acc max: 0.9147496706578019
# loss mean : 0.3231160772314576   acc mean: 0.8995940450297638
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.2828252318142554   acc max: 0.9093369405227681
# loss mean : 0.4114323066967427   acc mean: 0.878200270886431
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.3876885570515154   acc max: 0.898511500739277
# loss mean : 0.5672501090281872   acc mean: 0.8596346422114455
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4510600040584843   acc max: 0.9147496625922207
# loss mean : 0.6126343967175774   acc mean: 0.857713126728112
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.45107421714494933   acc max: 0.9079837707931199
# loss mean : 0.6221633084313956   acc mean: 0.8696075793701514
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.31455122779283534   acc max: 0.905277400603959
# loss mean : 0.5175347423819631   acc mean: 0.876359946951976
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.49881995167880644   acc max: 0.8836265166815628
# loss mean : 0.7125635621653359   acc mean: 0.8542083880680343
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 128   Dropout: 0
# loss min : 0.21236095052207435   acc max: 0.9269282798483182
# loss mean : 0.26930027934287815   acc mean: 0.9107036534423597
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.20886781057582335   acc max: 0.9296346411653398
# loss mean : 0.2863784675251728   acc mean: 0.9056562926143367
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.24427358001591548   acc max: 0.9147496587207418
# loss mean : 0.31648849361300146   acc mean: 0.902165088163177
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.2927378414448285   acc max: 0.9079837588560598
# loss mean : 0.45423283147957066   acc mean: 0.887672530483651
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2226324445985167   acc max: 0.9269282904142294
# loss mean : 0.288250364215795   acc mean: 0.908213801855002
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.22991696623165328   acc max: 0.9215155624569027
# loss mean : 0.323471560348153   acc mean: 0.9050067697318224
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.2513698457824684   acc max: 0.9161028425651571
# loss mean : 0.3639959643486791   acc mean: 0.8782273379319089
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.2972473297696636   acc max: 0.8985115109825651
# loss mean : 0.49217247621293636   acc mean: 0.8624221916450375
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.232705057473886   acc max: 0.918809210576611
# loss mean : 0.4194410935499993   acc mean: 0.8709742920739886
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.23836025829566831   acc max: 0.912043310711929
# loss mean : 0.33779287239574457   acc mean: 0.896982410908229
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.24998659609296486   acc max: 0.9161028425651571
# loss mean : 0.4132155534185479   acc mean: 0.8843301804619809
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.32137726140441686   acc max: 0.8958051488589853
# loss mean : 0.5374769302581579   acc mean: 0.8574830872336646
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 128   Dropout: 0
# loss min : 0.21603286502245153   acc max: 0.9282814611924033
# loss mean : 0.27336660342727037   acc mean: 0.9092963456180001
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.22755073359757863   acc max: 0.9228687413006578
# loss mean : 0.27743963565369906   acc mean: 0.9079566982578037
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.22763132536846828   acc max: 0.9188092052533275
# loss mean : 0.30507308979560294   acc mean: 0.90493910871678
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.2619283107564317   acc max: 0.910690125415709
# loss mean : 0.36574059575917106   acc mean: 0.8858592712556559
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 256   Dropout: 0
# loss min : 0.2177605846133058   acc max: 0.9255750964878376
# loss mean : 0.30182991540984466   acc mean: 0.9063870105490149
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.21605624847305643   acc max: 0.9282814542560035
# loss mean : 0.28017148656536184   acc mean: 0.9102706381408382
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.2392036368785595   acc max: 0.9174560144725123
# loss mean : 0.3351310459874237   acc mean: 0.8967658994767277
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.2846909490425306   acc max: 0.8998646748243391
# loss mean : 0.4682029583457358   acc mean: 0.8724357267460096
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2503793398283815   acc max: 0.9174560268935074
# loss mean : 0.3511847790063476   acc mean: 0.900744247996275
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.24337654430746872   acc max: 0.9147496706578019
# loss mean : 0.3650743997042572   acc mean: 0.8950879609633202
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.2583925148348686   acc max: 0.912043310711929
# loss mean : 0.3895666903785665   acc mean: 0.8885926946348361
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.5
# loss min : 0.3014842486954187   acc max: 0.9093369507660563
# loss mean : 0.5121793099001795   acc mean: 0.8673207044125573
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 128   Dropout: 0
# loss min : 0.22732272760309935   acc max: 0.9282814598212545
# loss mean : 0.26741990632814866   acc mean: 0.9105683353982856
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 128   Dropout: 0.1
# loss min : 0.20368768026767467   acc max: 0.9309878225094249
# loss mean : 0.25563665118527185   acc mean: 0.9132746948465119
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 128   Dropout: 0.3
# loss min : 0.22973400360434562   acc max: 0.9174560214089121
# loss mean : 0.2907120775172288   acc mean: 0.9020703653456877
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 128   Dropout: 0.5
# loss min : 0.2620990847379816   acc max: 0.9133964787478054
# loss mean : 0.3424171954655518   acc mean: 0.8935318011343882
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 256   Dropout: 0
# loss min : 0.21234087446384403   acc max: 0.9323409963525197
# loss mean : 0.2599933019671614   acc mean: 0.9154533165669088
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 256   Dropout: 0.1
# loss min : 0.2202806258032222   acc max: 0.9133964826192843
# loss mean : 0.2847240935211575   acc mean: 0.902760487371433
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 256   Dropout: 0.3
# loss min : 0.24875495860073338   acc max: 0.9201623846616732
# loss mean : 0.3419034049919074   acc mean: 0.9027604890950477
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 256   Dropout: 0.5
# loss min : 0.27839902353867463   acc max: 0.9079837627275387
# loss mean : 0.40395931170338384   acc mean: 0.8770500700657682
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.23043518982252992   acc max: 0.914749668480095
# loss mean : 0.3124999487742842   acc mean: 0.9016508829456543
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.22891356210263397   acc max: 0.9269282845263552
# loss mean : 0.328008465128516   acc mean: 0.9071989160050236
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.26032070378005423   acc max: 0.916102834499576
# loss mean : 0.38201408901580775   acc mean: 0.8935453346432144
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.5
