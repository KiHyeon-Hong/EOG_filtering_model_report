# %%
def featureExtraction(fileDir, minCount, maxCount, leftLight):
    userHp1 = []
    userLp1 = []
    userLhpl1 = []
    userLlpl1 = []
    userHpl1 = []
    userLpl1 = []
    userLhpg1 = []
    userLlpg1 = []
    userRhpg1 = []
    userRlpg1 = []
    userBlink1 = []
    userNotBlink1 = []
    
    for count in range(minCount, maxCount):
        file = open(fileDir + '/file' + str(count) + '-' + str(leftLight) + '.txt', 'r')
        x = file.read()
        file.close()
    
        x = x.split(',')
    
        data1 = []
    
        for index, item in enumerate(x):
            data1.append(float(item))
        
        for index, item in enumerate(x):
            if(index != len(data1) -1):
                data1[index] = data1[index + 1]
            
        temp = 0
        index = 0

        start1 = []
        middle1 = []
        finish1 = []

        for i in range(0, len(data1)):
            if((temp + 150 < i) and (data1[i] > 100)):
                for j in range(i, 0, -1):
                    if(data1[j] <= 0):
                        start1.append(j)
                        break
                
                for j in range(start1[index] + 1, len(data1)):
                    if(data1[j] <= 0):
                        middle1.append(j)
                        break
                
                for j in range(middle1[index] + 1, len(data1)):
                    if(data1[j] >= 0):
                        finish1.append(j)
                        break
                
                i = finish1[index]
                index = index + 1
                temp = i
   
        temp = 0
    
        hp1 = []
        lp1 = []
        lhpl1 = []
        llpl1 = []
        hpl1 = []
        lpl1 = []
        lhpg1 = []
        llpg1 = []
        rhpg1 = []
        rlpg1 = []
        blink1 = []
        notBlink1 = []
    
        index = 0;
    
        for i in range(start1[0], finish1[len(finish1) - 1]):
            hp1.append(0)
            lp1.append(0)
            lhpl1.append(0)
            llpl1.append(0)
            hpl1.append(0)
            lpl1.append(0)
            lhpg1.append(0)
            llpg1.append(0)
            rhpg1.append(0)
            rlpg1.append(0)
            blink1.append(0)
            notBlink1.append(0)
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] < data1[j]):
                    hp1[index] = data1[j]
                    lhpl1[index] = j - start1[index]
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] > data1[j]):
                    lp1[index] = data1[j]
                    llpl1[index] = j - start1[index]
            
            hpl1[index] = middle1[index] - start1[index]
            lpl1[index] = finish1[index] - middle1[index]
    
            lhpg1[index] = hp1[index] / lhpl1[index]
            llpg1[index] = lp1[index] / llpl1[index]
            rhpg1[index] = hp1[index] / (hpl1[index] - lhpg1[index])
            rlpg1[index] = lp1[index] / (lpl1[index] - llpl1[index])
    
            index = index + 1
    
            if(len(start1) == index):
                break
    
            i = start1[index]
        
        index = 0;
        
        for i in range(0, len(finish1)):
            blink1[i] = finish1[i] - start1[i]

        for i in range(0, len(finish1) - 1):
            notBlink1[i] = start1[i + 1] - finish1[i]
        
        for i in range(0, len(finish1)):
            userHp1.append(hp1[i])
            userLp1.append(lp1[i])
            userLhpl1.append(lhpl1[i])
            userLlpl1.append(llpl1[i])
            userHpl1.append(hpl1[i])
            userLpl1.append(lpl1[i])
            userLhpg1.append(lhpg1[i])
            userLlpg1.append(llpg1[i])
            userRhpg1.append(rhpg1[i])
            userRlpg1.append(rlpg1[i])
            userBlink1.append(blink1[i])
            userNotBlink1.append(notBlink1[i])
            
    return userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1

# %%
user1Data  = []
user1Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user1', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user1', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user1Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user1Label.append(0)

# %%
user2Data  = []
user2Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user2', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user2', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user2Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user2Label.append(1)

# %%
user3Data  = []
user3Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user3Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user3Label.append(2)

# %%
import numpy as np

# %%
user1Data = np.array(user1Data)
user2Data = np.array(user2Data)
user3Data = np.array(user3Data)

user1Label = np.array(user1Label)
user2Label = np.array(user2Label)
user3Label = np.array(user3Label)

# %%
data = np.concatenate((user1Data, user2Data, user3Data), axis=0)

# %%
len(data)
# Out:
# 3239

# %%
label = np.concatenate((user1Label, user2Label, user3Label), axis=0)

# %%
len(label)
# Out:
# 3239

# %%
s = np.arange(data.shape[0])
np.random.shuffle(s)

# %%
data = data[s]
label = label[s]

# %%
label
# Out:
# array([1, 2, 2, ..., 2, 1, 0])

# %%
tempLabel = []

# %%
for i in range(0, len(label)):
    if(label[i] == 0):
        tempLabel.append([1, 0, 0])
    elif(label[i] == 1):
        tempLabel.append([0, 1, 0])
    else:
        tempLabel.append([0, 0, 1])

# %%
label = tempLabel

# %%
label = np.array(label)

# %%
train_data = data[:2500]
val_data = data[2500:]

train_label = label[:2500]
val_label = label[2500:]

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

val_data -= mean
val_data /= std

# %%
from keras import models
from keras import layers
from keras import regularizers
from keras import optimizers

# %%
def build_model(actiFunc, lossFunc, hidden, node, dropout):
    model = models.Sequential()
    
    model.add(layers.Dense(node[0], activation=actiFunc, input_shape=(12, )))
    model.add(layers.Dropout(dropout))
    
    if(hidden == 2):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    if(hidden == 3):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
        model.add(layers.Dense(node[2], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='rmsprop', loss=lossFunc, metrics=['accuracy'])
    return model

# %%
import numpy as np

num_epochs = 100


actiFunc = ['relu', 'sigmoid', 'elu', 'selu']
lossFunc = ['categorical_crossentropy']
hidden = [3]
#node = [[4, 4], [4, 8], [4, 16], [4, 32], [8, 4], [8, 8], [8, 16], [8, 32], [16, 4], [16, 8], [16, 16], [16, 32], [32, 4], [32, 8], [32, 16], [32, 32]]
node = [
    [4, 4, 4], [4, 4, 8], [4, 4, 16], [4, 4, 32], [4, 8, 4], [4, 8, 8], [4, 8, 16], [4, 8, 32], [4, 16, 4], [4, 16, 8], [4, 16, 16], [4, 16, 32], [4, 32, 4], [4, 32, 8], [4, 32, 16], [4, 32, 32],
    [8, 4, 4], [8, 4, 8], [8, 4, 16], [8, 4, 32], [8, 8, 4], [8, 8, 8], [8, 8, 16], [8, 8, 32], [8, 16, 4], [8, 16, 8], [8, 16, 16], [8, 16, 32], [8, 32, 4], [8, 32, 8], [8, 32, 16], [8, 32, 32],
    [16, 4, 4], [16, 4, 8], [16, 4, 16], [16, 4, 32], [16, 8, 4], [16, 8, 8], [16, 8, 16], [16, 8, 32], [16, 16, 4], [16, 16, 8], [16, 16, 16], [16, 16, 32], [16, 32, 4], [16, 32, 8], [16, 32, 16], [16, 32, 32],
    [32, 4, 4], [32, 4, 8], [32, 4, 16], [32, 4, 32], [32, 8, 4], [32, 8, 8], [32, 8, 16], [32, 8, 32], [32, 16, 4], [32, 16, 8], [32, 16, 16], [32, 16, 32], [32, 32, 4], [32, 32, 8], [32, 32, 16], [32, 32, 32]
]
batchSize = [512]
dropout = [0, 0.1, 0.3]

all_acc_histories = []
all_loss_histories = []

for i in range(len(actiFunc)):
    for j in range(len(lossFunc)):
        for k in range(len(hidden)):
            for l in range(len(node)):
                for m in range(len(batchSize)):
                    for n in range(len(dropout)):
                        print('Activation:', actiFunc[i] , '  Loss:', lossFunc[j] , '  HiddenLayer:', hidden[k] , '  Node:[', node[l][0], ',', node[l][1] , ',', node[l][2], ']  BatchSize:', batchSize[m], '  Dropout:', dropout[n])
    
                        model = build_model(actiFunc[i], lossFunc[j], hidden[k], node[l], dropout[n])
                        history = model.fit(train_data, train_label, validation_data=(val_data, val_label), epochs=num_epochs, batch_size=batchSize[m], verbose=False)
    
                        acc_history = history.history['val_acc']
                        all_acc_histories.append(acc_history)
                        loss_history = history.history['val_loss']
                        all_loss_histories.append(loss_history)
    
                        print('loss min :', min(loss_history), '  acc max:', max(acc_history))
                        print('loss mean :', np.mean(loss_history), '  acc mean:', np.mean(acc_history))
    
                        print()
# Out:
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6503038603978809   acc max: 0.8497970188906131
# loss mean : 0.8903321969081648   acc mean: 0.6032476320475622
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.8009457800320585   acc max: 0.6671177186727201
# loss mean : 0.8875959012029297   acc mean: 0.6459404583648352
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.8126172187847762   acc max: 0.6644113587268473
# loss mean : 0.9604180975010334   acc mean: 0.5799594030054398
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.40003767964481823   acc max: 0.8755074346662374
# loss mean : 0.6978081130691085   acc mean: 0.7468876858682688
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.639549961674036   acc max: 0.6860622528925316
# loss mean : 0.8672155391694085   acc mean: 0.6036806495328395
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5867225331769744   acc max: 0.8565629246431694
# loss mean : 0.7979501305397534   acc mean: 0.7692828147845276
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.44076802306310736   acc max: 0.8660351742104361
# loss mean : 0.689507009773358   acc mean: 0.7615967495773738
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4607768464475588   acc max: 0.872801076252825
# loss mean : 0.6684258167742071   acc mean: 0.8029499310372004
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7250814062816687   acc max: 0.6657645511207787
# loss mean : 0.8448296297378888   acc mean: 0.6538430312586412
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.37083898260887   acc max: 0.875507446441986
# loss mean : 0.6136353226721851   acc mean: 0.7792692818709412
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4323134767912399   acc max: 0.8714479006353024
# loss mean : 0.6073289929896956   acc mean: 0.8056021650119386
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.623315014681087   acc max: 0.729364000250748
# loss mean : 0.7859006142374305   acc mean: 0.6350202961175303
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5355589464004372   acc max: 0.8673883585387864
# loss mean : 0.7595615793798869   acc mean: 0.7612178600132871
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6594949864728202   acc max: 0.6874154350431749
# loss mean : 0.90162474477646   acc mean: 0.5915967520446352
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7386931961702236   acc max: 0.8511502025737169
# loss mean : 0.8945728036055545   acc mean: 0.6100135304777807
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5473991535674574   acc max: 0.8497970247784874
# loss mean : 0.7894304925396899   acc mean: 0.6775372122209998
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.47462045767310507   acc max: 0.8673883563610795
# loss mean : 0.7039688985676824   acc mean: 0.7768200257549587
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6058523525888445   acc max: 0.8484438360947233
# loss mean : 0.8204611981850677   acc mean: 0.7306089281967271
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.34908560454764775   acc max: 0.8822733425965006
# loss mean : 0.620672668329111   acc mean: 0.7793910679717188
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.47293148892496856   acc max: 0.8606224543186906
# loss mean : 0.7665826563204416   acc mean: 0.7226657633957262
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5477647583765332   acc max: 0.8538565705851708
# loss mean : 0.7816655203696032   acc mean: 0.7395399193810513
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.36151679450991353   acc max: 0.8836265247471439
# loss mean : 0.547696803930809   acc mean: 0.8318267915084333
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.38969307004679526   acc max: 0.8836265145038559
# loss mean : 0.6110961485171189   acc mean: 0.7886738841112639
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6188246233537491   acc max: 0.8430311264462658
# loss mean : 0.8423826413959548   acc mean: 0.6861569673923903
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.49766222799905097   acc max: 0.876860620527048
# loss mean : 0.6518301361944421   acc mean: 0.7641271995010009
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.42844284395403726   acc max: 0.8782137983222775
# loss mean : 0.7040841785500754   acc mean: 0.7340866037769714
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.727950227196065   acc max: 0.673883620715109
# loss mean : 0.8211172144830792   acc mean: 0.6542489837470975
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.45138818315949913   acc max: 0.8782138004999844
# loss mean : 0.6434461022504128   acc mean: 0.7717591332304462
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4896005027510317   acc max: 0.8484438463380114
# loss mean : 0.6887448136990382   acc mean: 0.7849255727419029
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6332872448657944   acc max: 0.8484438506934252
# loss mean : 0.8008889509150721   acc mean: 0.6839106908347837
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4226845409292652   acc max: 0.8673883666043675
# loss mean : 0.6574467874154025   acc mean: 0.7593640042125613
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4382206325360016   acc max: 0.8633288245078514
# loss mean : 0.5996017364853129   acc mean: 0.8328687401432469
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5610017720836747   acc max: 0.8592692765234611
# loss mean : 0.7507000845775552   acc mean: 0.7555615684152136
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3528074569324679   acc max: 0.8673883709597814
# loss mean : 0.5487056741638662   acc mean: 0.8163058182855261
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3927504602159312   acc max: 0.8606224689173925
# loss mean : 0.5937400322321786   acc mean: 0.8155886329805254
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5029218977617153   acc max: 0.8700947141292453
# loss mean : 0.6951502308834228   acc mean: 0.753829498385383
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.56084718223515   acc max: 0.8579161105039801
# loss mean : 0.7994276610028921   acc mean: 0.75623816192997
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.44611537291168035   acc max: 0.8633288245078514
# loss mean : 0.6503642750959918   acc mean: 0.8202977001239546
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6657304910587523   acc max: 0.8281461504541328
# loss mean : 0.8470820312587108   acc mean: 0.6507307160247484
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.35751268380549667   acc max: 0.8836265284573113
# loss mean : 0.6434114941361793   acc mean: 0.762232748990291
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.35568611136308703   acc max: 0.8741542686467564
# loss mean : 0.5883081104423905   acc mean: 0.8063599453352304
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4953937472445394   acc max: 0.8660351742104361
# loss mean : 0.6606923809264446   acc mean: 0.8001217852341307
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3004660786246737   acc max: 0.898511500739277
# loss mean : 0.5048444496032672   acc mean: 0.8287009458741896
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4038250705628014   acc max: 0.8700947287279472
# loss mean : 0.6969941747446667   acc mean: 0.7502165081230002
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.47299633853651674   acc max: 0.872801078430532
# loss mean : 0.6475810370046813   acc mean: 0.8069688761843234
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3298390050379607   acc max: 0.8795669745850466
# loss mean : 0.5231079782769386   acc mean: 0.8306089315999988
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.34529606467654805   acc max: 0.8782138085655656
# loss mean : 0.5091927139063811   acc mean: 0.8395669831353691
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.42632774421907405   acc max: 0.8619756423572081
# loss mean : 0.5922939498889914   acc mean: 0.8173748281702942
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5603266065594953   acc max: 0.822733420319099
# loss mean : 0.8069644155441021   acc mean: 0.6357510149035305
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6142967315907407   acc max: 0.8633288245078514
# loss mean : 0.8681481602412923   acc mean: 0.6676454658134863
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6897713025787364   acc max: 0.8457374863921386
# loss mean : 0.872097757127998   acc mean: 0.7765087958154078
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3867422779858193   acc max: 0.8700947243725334
# loss mean : 0.6144992234653645   acc mean: 0.8049526385529439
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5896764151620929   acc max: 0.837618398488939
# loss mean : 0.7962664443746469   acc mean: 0.6504059546226094
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.581886231657294   acc max: 0.8294993267169019
# loss mean : 0.7548634785381481   acc mean: 0.8077672501555636
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.37752126816645043   acc max: 0.8958051386156972
# loss mean : 0.6374203676166811   acc mean: 0.7961163729723638
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4379208871492352   acc max: 0.879566988538502
# loss mean : 0.6449677365409343   acc mean: 0.7586468202202341
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5399597215394367   acc max: 0.8700947228400729
# loss mean : 0.7729939904070998   acc mean: 0.7801217860910984
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3439648910772171   acc max: 0.8863328846930167
# loss mean : 0.5567002005969881   acc mean: 0.8032476301315836
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4119053284192763   acc max: 0.8673883687820745
# loss mean : 0.564755464816045   acc mean: 0.8170771305002928
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5239028690309744   acc max: 0.859269288944456
# loss mean : 0.7315960635609813   acc mean: 0.7368876862570297
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4009217690066491   acc max: 0.8863328846930167
# loss mean : 0.6483547138466079   acc mean: 0.7866441151286011
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5163129601975417   acc max: 0.8714479065231767
# loss mean : 0.76739011274381   acc mean: 0.7003382964030975
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7201312402104493   acc max: 0.663058188997199
# loss mean : 0.8678363832391809   acc mean: 0.6342625161614243
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5381997926954649   acc max: 0.8700947265502403
# loss mean : 0.7652697849781812   acc mean: 0.6732205675693582
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3900890904043944   acc max: 0.8836265145038559
# loss mean : 0.5982238264105639   acc mean: 0.813937752623116
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5815806479996047   acc max: 0.8443843085969092
# loss mean : 0.8092901811765882   acc mean: 0.6769824082925614
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.33256029449554514   acc max: 0.8849796944767923
# loss mean : 0.5917523616987894   acc mean: 0.8065223279980509
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.38541185480815954   acc max: 0.8673883687820745
# loss mean : 0.6254822771321776   acc mean: 0.7848579149321224
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43889745194792584   acc max: 0.8673883644266606
# loss mean : 0.6425603650738164   acc mean: 0.8019079818273107
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29126423944155805   acc max: 0.8849797025423733
# loss mean : 0.48651079177493495   acc mean: 0.8530040610856876
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3248779350672426   acc max: 0.8863328846930167
# loss mean : 0.553369761155326   acc mean: 0.8068606227442765
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4894585520714642   acc max: 0.8673883687820745
# loss mean : 0.6733789253896244   acc mean: 0.7705818677134054
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.44768469202986266   acc max: 0.8876860705538273
# loss mean : 0.6195021900631417   acc mean: 0.8100270652359651
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4268864254506257   acc max: 0.8822733484843749
# loss mean : 0.6214293598108427   acc mean: 0.8033423533725158
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5952500347678168   acc max: 0.8673883644266606
# loss mean : 0.7977320745212299   acc mean: 0.7229228702014125
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.30985642778050754   acc max: 0.8890392402834757
# loss mean : 0.5018102087675316   acc mean: 0.8371989183746916
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3501681893942966   acc max: 0.8768606285926293
# loss mean : 0.5757886902683481   acc mean: 0.8058863337368214
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4672342832017493   acc max: 0.8700947250177798
# loss mean : 0.671847106501843   acc mean: 0.7921244908968069
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2911610074633674   acc max: 0.8890392424611826
# loss mean : 0.518344408346287   acc mean: 0.8427334246527358
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.31593224507062134   acc max: 0.8930987823799917
# loss mean : 0.5107631862405512   acc mean: 0.8578755068738663
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.45456756673581866   acc max: 0.876860622704755
# loss mean : 0.6575999537517638   acc mean: 0.8189174574629701
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3150966540886359   acc max: 0.8863328803376028
# loss mean : 0.49516516450616116   acc mean: 0.8444519623400234
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3480030228062476   acc max: 0.8755074507973998
# loss mean : 0.5138018441301075   acc mean: 0.8443301768683611
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.38411337113025545   acc max: 0.8795669907162089
# loss mean : 0.5546677086325879   acc mean: 0.8181461439770679
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.34210384448584424   acc max: 0.8863328803376028
# loss mean : 0.5090223883542059   acc mean: 0.8632882266857628
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3319653153661462   acc max: 0.8917456002293485
# loss mean : 0.6086707445204823   acc mean: 0.7948714482542303
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.668824577041182   acc max: 0.6860622448269504
# loss mean : 0.7690483335656628   acc mean: 0.649837621529467
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3150619797519483   acc max: 0.8755074486196929
# loss mean : 0.49440984437486635   acc mean: 0.843761839938422
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3228539473632998   acc max: 0.8958051466812784
# loss mean : 0.5315240848516095   acc mean: 0.8311907969364779
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4336096260479887   acc max: 0.8660351763881431
# loss mean : 0.5914548569820891   acc mean: 0.8383897142086041
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3250728492323859   acc max: 0.8917456067624692
# loss mean : 0.44790666753166597   acc mean: 0.8732205692881336
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2837891779507287   acc max: 0.8944519645306351
# loss mean : 0.508788032405512   acc mean: 0.8487009461455963
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.41225339708212105   acc max: 0.8728010864961131
# loss mean : 0.5576452912880216   acc mean: 0.8394857905504665
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.27488187516009854   acc max: 0.9039242162756087
# loss mean : 0.41823495835751423   acc mean: 0.8624221906485349
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.32025229971205593   acc max: 0.8741542686467564
# loss mean : 0.4820593005979335   acc mean: 0.8294587281995599
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3877742390913312   acc max: 0.8714478984575955
# loss mean : 0.5280492595031716   acc mean: 0.8492422177278622
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5336847781973698   acc max: 0.8673883687820745
# loss mean : 0.7669633918444102   acc mean: 0.6705277407741999
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48738491091579805   acc max: 0.8822733506620818
# loss mean : 0.6970377607452046   acc mean: 0.7627875512656889
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.8123842147109634   acc max: 0.6644113689701354
# loss mean : 0.8883464241003634   acc mean: 0.6473071708807442
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.32595253055247303   acc max: 0.8822733447742075
# loss mean : 0.5902616757924728   acc mean: 0.8133152918136491
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.39961058990235904   acc max: 0.8660351866314311
# loss mean : 0.5976957851962887   acc mean: 0.832882272209947
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5350978395451712   acc max: 0.8565629305310436
# loss mean : 0.762072152596204   acc mean: 0.7745196219566951
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.35389079570931575   acc max: 0.887686054422665
# loss mean : 0.576572417025637   acc mean: 0.8199323411404846
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.34882166070286413   acc max: 0.8714479065231767
# loss mean : 0.5872721135721154   acc mean: 0.8039783478738972
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4748778129462783   acc max: 0.8700947163069522
# loss mean : 0.6936459703084096   acc mean: 0.7694451956977217
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2825827354991226   acc max: 0.9025710465459604
# loss mean : 0.44566847104664903   acc mean: 0.8628281450820066
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3220081592686928   acc max: 0.8809201706891453
# loss mean : 0.5097783397519217   acc mean: 0.846603517989667
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4243747086260412   acc max: 0.8768606285926293
# loss mean : 0.6345060995680877   acc mean: 0.7755480386818858
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2972075676240521   acc max: 0.8917456067624692
# loss mean : 0.5452389176970244   acc mean: 0.80307171912574
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.35624885232425996   acc max: 0.8930987845576988
# loss mean : 0.5624493082474631   acc mean: 0.8204330162621316
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4928390632946856   acc max: 0.8768606285926293
# loss mean : 0.668440246100516   acc mean: 0.8444519607712674
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3331873980684758   acc max: 0.887686054422665
# loss mean : 0.6430799302224861   acc mean: 0.7884032472556757
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.34700766665525784   acc max: 0.8782138042101518
# loss mean : 0.5597030518878459   acc mean: 0.8176589974994911
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4758323343906738   acc max: 0.8728010806082389
# loss mean : 0.7446967467790688   acc mean: 0.7745737475305998
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.30682419077146683   acc max: 0.8890392424611826
# loss mean : 0.5053952962152044   acc mean: 0.8605548052544201
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2993266676856313   acc max: 0.8849797106079546
# loss mean : 0.5030939062308716   acc mean: 0.8452774037309847
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4139958058303683   acc max: 0.8782138107432725
# loss mean : 0.6496050450822818   acc mean: 0.7816508785632209
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.28414520137364874   acc max: 0.9039242162756087
# loss mean : 0.45413805707220456   acc mean: 0.8613396464108776
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3259463980894773   acc max: 0.8809201685114384
# loss mean : 0.5288216475874227   acc mean: 0.818673883452709
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.37398948309708674   acc max: 0.8849796944767923
# loss mean : 0.5785072926102214   acc mean: 0.8108525041322426
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.28111315918872093   acc max: 0.901217866573024
# loss mean : 0.5075596760699326   acc mean: 0.8315967514554441
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.38875658336285807   acc max: 0.8809201604458573
# loss mean : 0.6300560658819299   acc mean: 0.7843572391914418
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5999421283743862   acc max: 0.8646819964152066
# loss mean : 0.7847318855714411   acc mean: 0.7207171850715018
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2875637738323986   acc max: 0.8930987743144106
# loss mean : 0.44926305475552764   acc mean: 0.8644113671771566
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29298041835528105   acc max: 0.8863328905808909
# loss mean : 0.5292081267000536   acc mean: 0.8398917460481917
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4106717777510296   acc max: 0.8809201648012711
# loss mean : 0.6832952594103767   acc mean: 0.7740324761644912
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26658371986168483   acc max: 0.9039242286966037
# loss mean : 0.4278552007171071   acc mean: 0.8565087954282599
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2841739984826564   acc max: 0.8917456024070554
# loss mean : 0.4617906834985633   acc mean: 0.8534912058545708
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.37401553706161383   acc max: 0.8876860624882462
# loss mean : 0.572841506275337   acc mean: 0.8318403243179732
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26393634395444504   acc max: 0.9120433026463479
# loss mean : 0.39104398619882635   acc mean: 0.8828552094170464
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.28296018372691856   acc max: 0.8971583244765079
# loss mean : 0.43879890758670226   acc mean: 0.8513261158564738
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3274083074197395   acc max: 0.8930987867354057
# loss mean : 0.5094507561569608   acc mean: 0.8360757776502021
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.28527285600224755   acc max: 0.8958051488589853
# loss mean : 0.4500186022091783   acc mean: 0.8465358582179343
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.32205929904571245   acc max: 0.894451966708342
# loss mean : 0.513838552142593   acc mean: 0.8138565627518785
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3889224582095914   acc max: 0.8863328803376028
# loss mean : 0.6036110002282347   acc mean: 0.7961569697209238
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26081682679133744   acc max: 0.909336934634894
# loss mean : 0.48860736989442644   acc mean: 0.8564411366155248
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.26329923030971997   acc max: 0.9012178643953171
# loss mean : 0.42057065784648884   acc mean: 0.8694046006179308
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3824267138970237   acc max: 0.8809201685114384
# loss mean : 0.6213544083081176   acc mean: 0.8262787550586969
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26056997488090244   acc max: 0.905277400603959
# loss mean : 0.3818218502603944   acc mean: 0.8723139377763051
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.26137070642111265   acc max: 0.8985115044494443
# loss mean : 0.4053799714319438   acc mean: 0.8699458712492648
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3104192483086386   acc max: 0.8822733506620818
# loss mean : 0.49979795025835505   acc mean: 0.8263734801301128
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2665951803266115   acc max: 0.912043300468641
# loss mean : 0.37285101253544367   acc mean: 0.8838024367579588
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.26297557874203376   acc max: 0.9106901226734115
# loss mean : 0.41615366273828064   acc mean: 0.8678213801693692
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.2937695249733647   acc max: 0.8958051342602834
# loss mean : 0.4687956744642154   acc mean: 0.8536806508644671
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2963172301791195   acc max: 0.901217866573024
# loss mean : 0.5137151758536112   acc mean: 0.8265087952806596
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.35815409479186405   acc max: 0.8971583266542148
# loss mean : 0.6264660794567191   acc mean: 0.7791069006024582
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5601586041334357   acc max: 0.8673883585387864
# loss mean : 0.7120468579908185   acc mean: 0.8423274678076553
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.339709326322411   acc max: 0.8836265284573113
# loss mean : 0.6157054664624076   acc mean: 0.831353181141639
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29192664731339285   acc max: 0.8930987867354057
# loss mean : 0.5140318972739379   acc mean: 0.8215561576552579
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5261512187401561   acc max: 0.8782138085655656
# loss mean : 0.7023923342936094   acc mean: 0.7565493905503954
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3100731955571491   acc max: 0.8944519586427608
# loss mean : 0.5671286162838886   acc mean: 0.7924492560316971
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.39521648189373043   acc max: 0.8958051445035715
# loss mean : 0.6107163175150087   acc mean: 0.7847361300573135
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3932949855459882   acc max: 0.8673883666043675
# loss mean : 0.5514878829628108   acc mean: 0.8415290941489567
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.286323544056393   acc max: 0.909336934634894
# loss mean : 0.45604749943632555   acc mean: 0.8591339661820169
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.318690948581502   acc max: 0.8876860705538273
# loss mean : 0.5011854167062794   acc mean: 0.8318673879170287
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.40664953703164086   acc max: 0.897158322298801
# loss mean : 0.5952534790439922   acc mean: 0.8012043298468379
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4861177750466157   acc max: 0.8849796944767923
# loss mean : 0.7387116080478177   acc mean: 0.7585115029206135
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.46694890805929695   acc max: 0.8849797003646664
# loss mean : 0.6857158734700836   acc mean: 0.7931935051672352
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3937181148864581   acc max: 0.8741542686467564
# loss mean : 0.5860725207068278   acc mean: 0.8506359936194103
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.27867603870625424   acc max: 0.9039242286966037
# loss mean : 0.523015066780886   acc mean: 0.8224492549549421
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.27684203681507036   acc max: 0.8998646763567996
# loss mean : 0.4622858335390304   acc mean: 0.8511231401332822
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.36409202226121307   acc max: 0.8809201706891453
# loss mean : 0.5602668958047408   acc mean: 0.8461163735905906
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.25996727945033526   acc max: 0.9188091966231556
# loss mean : 0.41577001664248137   acc mean: 0.8696346401152012
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.27254498392061227   acc max: 0.905277400603959
# loss mean : 0.42064807805543986   acc mean: 0.8666576456390473
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3180776111005285   acc max: 0.8903924143685378
# loss mean : 0.49493076602886754   acc mean: 0.8581596752319672
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26702657717006617   acc max: 0.9147496625922207
# loss mean : 0.4145091413778124   acc mean: 0.8797564291123282
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.28271117084565117   acc max: 0.8971583244765079
# loss mean : 0.4667872071266175   acc mean: 0.8420568316231238
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3350655909965422   acc max: 0.8782138085655656
# loss mean : 0.5126085719760604   acc mean: 0.8486468199093059
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.35266480587816046   acc max: 0.9106901285612857
# loss mean : 0.5294801313810161   acc mean: 0.8552232748758002
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.40547420009869845   acc max: 0.8971583244765079
# loss mean : 0.5514011332529808   acc mean: 0.8366711772036646
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3671860116583085   acc max: 0.8876860705538273
# loss mean : 0.5647519459566341   acc mean: 0.8458998658583678
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26557512038938086   acc max: 0.9066305908201835
# loss mean : 0.4064374594271425   acc mean: 0.8767523671640273
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.28446596316458894   acc max: 0.8930987845576988
# loss mean : 0.4267162649024968   acc mean: 0.8681461433294018
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3386085971040558   acc max: 0.8822733506620818
# loss mean : 0.5369761146312637   acc mean: 0.8282002717183954
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2533251014468796   acc max: 0.9106901226734115
# loss mean : 0.39751437399460765   acc mean: 0.8758186742836793
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.265633401835239   acc max: 0.901217868750731
# loss mean : 0.42564979819870763   acc mean: 0.8767794313942144
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3126072597681105   acc max: 0.8863328846930167
# loss mean : 0.5152189035618903   acc mean: 0.8454803785713988
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26299212449539017   acc max: 0.9066305886424766
# loss mean : 0.3986344538929497   acc mean: 0.864763195850207
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2648471964066987   acc max: 0.894451966708342
# loss mean : 0.4078565082901708   acc mean: 0.8653721234827465
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.28715555343640836   acc max: 0.8903924246118259
# loss mean : 0.44558157777310375   acc mean: 0.8502029784308074
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.27011922614822853   acc max: 0.9147496567043465
# loss mean : 0.39365615062929793   acc mean: 0.8850744252146822
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3165905554255871   acc max: 0.8917456067624692
# loss mean : 0.4915385980716578   acc mean: 0.8553450595163042
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3094440288488855   acc max: 0.9106901263835788
# loss mean : 0.4839265395295636   acc mean: 0.8589715833342931
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26465391398928   acc max: 0.9106901226734115
# loss mean : 0.35803768434931044   acc mean: 0.8899594044766019
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.26459454300439084   acc max: 0.9106901183179976
# loss mean : 0.43872625725275777   acc mean: 0.8313261168497502
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.30473925215626924   acc max: 0.894451954287347
# loss mean : 0.5122623266628533   acc mean: 0.831650880852636
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26673088195520744   acc max: 0.9052774086695401
# loss mean : 0.3713644839151787   acc mean: 0.8805818681057961
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.24998914495775923   acc max: 0.916102844742864
# loss mean : 0.3808701140839853   acc mean: 0.8809607582445558
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.29378285209606725   acc max: 0.8890392446388895
# loss mean : 0.41818196188935736   acc mean: 0.8761705014444331
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.26653260121648786   acc max: 0.9133964869746981
# loss mean : 0.36387923539370415   acc mean: 0.8886062248166101
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.25116825027136747   acc max: 0.9201623846616732
# loss mean : 0.35544630460995613   acc mean: 0.88829499261547
#
# Activation: relu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.2768469188710188   acc max: 0.8985115066271512
# loss mean : 0.4125014491030425   acc mean: 0.8749797020108515
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.96485158200193   acc max: 0.5859269270716243
# loss mean : 1.0280604185020812   acc mean: 0.47734776342431323
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.9324693652386594   acc max: 0.6048714429825666
# loss mean : 1.020058383456909   acc mean: 0.47710419107515856
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 1.0440673029632466   acc max: 0.46955344637450086
# loss mean : 1.05581127976855   acc mean: 0.4695534463745008
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.9883910643393036   acc max: 0.4749661706216603
# loss mean : 1.0873932090921878   acc mean: 0.4212043277977767
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.9612982980453274   acc max: 0.5805142028244649
# loss mean : 1.0500891275447823   acc mean: 0.47063599076016194
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# ...
# loss min : 0.7126812289628995   acc max: 0.6711772607692362
# loss mean : 0.9123566990873003   acc mean: 0.5659269258851771
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7252805888733457   acc max: 0.6684709088889446
# loss mean : 0.9495860045809544   acc mean: 0.5355209729031071
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.743070980128158   acc max: 0.6617050068465556
# loss mean : 0.914977614116604   acc mean: 0.5653991865994804
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.7206490910908204   acc max: 0.667117720850427
# loss mean : 0.883643818708976   acc mean: 0.5832205664050918
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.8110930504269787   acc max: 0.6562922847771031
# loss mean : 0.9868980450567277   acc mean: 0.506738835172337
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.8496576841209835   acc max: 0.6684708986456566
# loss mean : 0.9808341119810434   acc mean: 0.5450202951831328
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.7869814907746322   acc max: 0.6576454728156207
# loss mean : 1.005738848125983   acc mean: 0.4978078477078588
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.735943354273036   acc max: 0.6617050149121368
# loss mean : 0.931104832056088   acc mean: 0.546332880799559
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.813390792787317   acc max: 0.6589986549662641
# loss mean : 0.9847232382957277   acc mean: 0.5084573715703412
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6578649597819668   acc max: 0.6711772710125243
# loss mean : 0.886530586600465   acc mean: 0.57495263709509
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.69854847383112   acc max: 0.6806495227574979
# loss mean : 0.8907733338651864   acc mean: 0.5858322042255021
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7551412343656259   acc max: 0.6576454749933276
# loss mean : 0.9506643306950917   acc mean: 0.5367253039509099
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6377881039463296   acc max: 0.7388362585288424
# loss mean : 0.8318486137238504   acc mean: 0.6133152899581621
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7076000305086737   acc max: 0.6684709110666515
# loss mean : 0.8932673414182598   acc mean: 0.5761163705627717
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7328106985201855   acc max: 0.6657645408774906
# loss mean : 0.9243593869593211   acc mean: 0.5643031096926239
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.725405634094801   acc max: 0.822733420319099
# loss mean : 0.9418123522388758   acc mean: 0.5668335572215798
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.881088215943441   acc max: 0.6535859328968116
# loss mean : 1.054537963933325   acc mean: 0.45442489671247427
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7666575941729772   acc max: 0.663058188997199
# loss mean : 0.9355414359430821   acc mean: 0.5434641393281127
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6462922029308118   acc max: 0.8335588688134179
# loss mean : 0.9069402283639805   acc mean: 0.5678619746377891
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.706937506169847   acc max: 0.6657645489430718
# loss mean : 0.8834260747824696   acc mean: 0.5782137994252458
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7284085502966492   acc max: 0.6644113667924285
# loss mean : 0.9384266403700566   acc mean: 0.53040595283447
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6152134744175716   acc max: 0.8132611605085442
# loss mean : 0.8561071888310015   acc mean: 0.6063734758283352
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.669938879906728   acc max: 0.6820027027304344
# loss mean : 0.8713809086924799   acc mean: 0.5773477652681052
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7319591988246076   acc max: 0.663058186819492
# loss mean : 0.8877703104225644   acc mean: 0.5797428943702754
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6193542715177162   acc max: 0.8294993223614879
# loss mean : 0.7810739802120504   acc mean: 0.6607983770813284
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6789934643227935   acc max: 0.6617050068465556
# loss mean : 0.8352182419003265   acc mean: 0.6038565625203962
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7069899925359693   acc max: 0.667117720850427
# loss mean : 0.8610021272200852   acc mean: 0.5858727978913968
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.7509071609970681   acc max: 0.6738836228928159
# loss mean : 0.9359366745732635   acc mean: 0.5647902556068197
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7259931540940869   acc max: 0.6752368131090404
# loss mean : 0.8883362051776039   acc mean: 0.5920703648597364
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.8006652027408874   acc max: 0.6549391150474548
# loss mean : 0.9683713798852025   acc mean: 0.50320703479692
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6240920724500983   acc max: 0.7834912085242781
# loss mean : 0.8544052370507598   acc mean: 0.5927334230307475
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.645678472131773   acc max: 0.6833558929466588
# loss mean : 0.8525037376241852   acc mean: 0.5981055455762737
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7298388999757005   acc max: 0.6603518268736193
# loss mean : 0.8773259077980328   acc mean: 0.5745060891856685
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6130966013436066   acc max: 0.8281461504541328
# loss mean : 0.8197551608972847   acc mean: 0.6203518252576802
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6062528961243584   acc max: 0.8322056764194865
# loss mean : 0.8219123226880061   acc mean: 0.614560215773618
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.683682705778553   acc max: 0.6644113689701354
# loss mean : 0.8661482308367432   acc mean: 0.5797022997643371
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.560161660746728   acc max: 0.8470906685427819
# loss mean : 0.7731259285056704   acc mean: 0.6651962102649175
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6170036914545403   acc max: 0.8254397905082599
# loss mean : 0.775800745082321   acc mean: 0.6685656300235503
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7040215693565441   acc max: 0.6684709088889446
# loss mean : 0.8436539148316493   acc mean: 0.6054668450089365
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.802505862406368   acc max: 0.6644113689701354
# loss mean : 0.9632016448956865   acc mean: 0.5349797011075065
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.8076410033867388   acc max: 0.6644113609045542
# loss mean : 0.945669806723827   acc mean: 0.5496617032690364
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.9444592841907187   acc max: 0.47496617171051375
# loss mean : 1.079977106652821   acc mean: 0.39972936153936117
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.7115116387968619   acc max: 0.6738836228928159
# loss mean : 0.8711040355880141   acc mean: 0.6047496612061505
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7647831849703447   acc max: 0.6684709110666515
# loss mean : 0.9369536168197817   acc mean: 0.555859266857091
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7763125468978056   acc max: 0.6671177289160082
# loss mean : 0.941980409595576   acc mean: 0.5523951268421942
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6814059140072463   acc max: 0.673883633136104
# loss mean : 0.8807099388190953   acc mean: 0.5843843017544734
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7224320018404391   acc max: 0.669824091039588
# loss mean : 0.9106447953711668   acc mean: 0.5589851137112538
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7730544636149529   acc max: 0.6603518188080381
# loss mean : 0.9655712872945245   acc mean: 0.524993232624134
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6253696596993483   acc max: 0.8037888963425757
# loss mean : 0.8368984252770956   acc mean: 0.6057510139667133
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.698280384237292   acc max: 0.6779431730549133
# loss mean : 0.8840334973130399   acc mean: 0.5821650868021103
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7273664230906753   acc max: 0.669824091039588
# loss mean : 0.8917476677168691   acc mean: 0.5869688750995027
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.7147592588432425   acc max: 0.6725304488077538
# loss mean : 0.8830588775453774   acc mean: 0.602097427908316
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7704780854294845   acc max: 0.6752368028657524
# loss mean : 0.9388895754941585   acc mean: 0.5684709050174657
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.771716686321047   acc max: 0.6657645408774906
# loss mean : 0.899850260463716   acc mean: 0.5788092003155787
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6927068372217986   acc max: 0.669824091039588
# loss mean : 0.8806116097496068   acc mean: 0.5746549390943995
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.725494225954332   acc max: 0.6644113609045542
# loss mean : 0.9218069211862406   acc mean: 0.5393504712751818
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7401100673759419   acc max: 0.6725304488077538
# loss mean : 0.9108511067799848   acc mean: 0.5789986461562298
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6084967808891214   acc max: 0.8132611642187116
# loss mean : 0.8392589353321372   acc mean: 0.6035588644366302
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6541642139341899   acc max: 0.6752368050434593
# loss mean : 0.8471205260789121   acc mean: 0.5936400538041724
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7240851791688974   acc max: 0.6684709088889446
# loss mean : 0.8696535110489765   acc mean: 0.5954803775434405
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5729301934797161   acc max: 0.8457374907475524
# loss mean : 0.7949186879533553   acc mean: 0.644411365364014
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.65222892685414   acc max: 0.7496617107333285
# loss mean : 0.8281415842084341   acc mean: 0.6049661689678129
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.7135541219672589   acc max: 0.6657645489430718
# loss mean : 0.8801161984484316   acc mean: 0.58012178531398
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6787087906842625   acc max: 0.6792963449622684
# loss mean : 0.8475687928403022   acc mean: 0.60066305708861
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.7261851969526649   acc max: 0.6711772688348174
# loss mean : 0.9357257707346439   acc mean: 0.555331529605937
#
# Activation: sigmoid   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
