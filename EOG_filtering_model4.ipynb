# %%
def featureExtraction(fileDir, minCount, maxCount, leftLight):
    userHp1 = []
    userLp1 = []
    userLhpl1 = []
    userLlpl1 = []
    userHpl1 = []
    userLpl1 = []
    userLhpg1 = []
    userLlpg1 = []
    userRhpg1 = []
    userRlpg1 = []
    userBlink1 = []
    userNotBlink1 = []
    
    for count in range(minCount, maxCount):
        file = open(fileDir + '/file' + str(count) + '-' + str(leftLight) + '.txt', 'r')
        x = file.read()
        file.close()
    
        x = x.split(',')
    
        data1 = []
    
        for index, item in enumerate(x):
            data1.append(float(item))
        
        for index, item in enumerate(x):
            if(index != len(data1) -1):
                data1[index] = data1[index + 1]
            
        temp = 0
        index = 0

        start1 = []
        middle1 = []
        finish1 = []

        for i in range(0, len(data1)):
            if((temp + 150 < i) and (data1[i] > 100)):
                for j in range(i, 0, -1):
                    if(data1[j] <= 0):
                        start1.append(j)
                        break
                
                for j in range(start1[index] + 1, len(data1)):
                    if(data1[j] <= 0):
                        middle1.append(j)
                        break
                
                for j in range(middle1[index] + 1, len(data1)):
                    if(data1[j] >= 0):
                        finish1.append(j)
                        break
                
                i = finish1[index]
                index = index + 1
                temp = i
   
        temp = 0
    
        hp1 = []
        lp1 = []
        lhpl1 = []
        llpl1 = []
        hpl1 = []
        lpl1 = []
        lhpg1 = []
        llpg1 = []
        rhpg1 = []
        rlpg1 = []
        blink1 = []
        notBlink1 = []
    
        index = 0;
    
        for i in range(start1[0], finish1[len(finish1) - 1]):
            hp1.append(0)
            lp1.append(0)
            lhpl1.append(0)
            llpl1.append(0)
            hpl1.append(0)
            lpl1.append(0)
            lhpg1.append(0)
            llpg1.append(0)
            rhpg1.append(0)
            rlpg1.append(0)
            blink1.append(0)
            notBlink1.append(0)
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] < data1[j]):
                    hp1[index] = data1[j]
                    lhpl1[index] = j - start1[index]
    
            for j in range(start1[index], finish1[index]):
                if(hp1[index] > data1[j]):
                    lp1[index] = data1[j]
                    llpl1[index] = j - start1[index]
            
            hpl1[index] = middle1[index] - start1[index]
            lpl1[index] = finish1[index] - middle1[index]
    
            lhpg1[index] = hp1[index] / lhpl1[index]
            llpg1[index] = lp1[index] / llpl1[index]
            rhpg1[index] = hp1[index] / (hpl1[index] - lhpg1[index])
            rlpg1[index] = lp1[index] / (lpl1[index] - llpl1[index])
    
            index = index + 1
    
            if(len(start1) == index):
                break
    
            i = start1[index]
        
        index = 0;
        
        for i in range(0, len(finish1)):
            blink1[i] = finish1[i] - start1[i]

        for i in range(0, len(finish1) - 1):
            notBlink1[i] = start1[i + 1] - finish1[i]
        
        for i in range(0, len(finish1)):
            userHp1.append(hp1[i])
            userLp1.append(lp1[i])
            userLhpl1.append(lhpl1[i])
            userLlpl1.append(llpl1[i])
            userHpl1.append(hpl1[i])
            userLpl1.append(lpl1[i])
            userLhpg1.append(lhpg1[i])
            userLlpg1.append(llpg1[i])
            userRhpg1.append(rhpg1[i])
            userRlpg1.append(rlpg1[i])
            userBlink1.append(blink1[i])
            userNotBlink1.append(notBlink1[i])
            
    return userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1

# %%
user1Data  = []
user1Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user1', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user1', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user1Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user1Label.append(0)

# %%
user2Data  = []
user2Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/user2', 0, 49, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/user2', 0, 49, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user2Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user2Label.append(1)

# %%
user3Data  = []
user3Label = []

# %%
userHp1, userLp1, userLhpl1, userLlpl1, userHpl1, userLpl1, userLhpg1, userLlpg1, userRhpg1, userRlpg1, userBlink1, userNotBlink1 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 1)

# %%
userHp2, userLp2, userLhpl2, userLlpl2, userHpl2, userLpl2, userLhpg2, userLlpg2, userRhpg2, userRlpg2, userBlink2, userNotBlink2 = featureExtraction('C:/EOGData/artifact/doridori', 0, 3, 2)

# %%
sum = len(userHp1) +len(userHp2)

# %%
userHp1 = userHp1 + userHp2
userLp1 = userLp1 + userLp2
userLhpl1 = userLhpl1 + userLhpl2
userLlpl1 = userLlpl1 + userLlpl2
userHpl1 = userHpl1 + userHpl2
userLpl1 = userLpl1 + userLpl2
userLhpg1 = userLhpg1 + userLhpg2
userLlpg1 = userLlpg1 + userLlpg2
userRhpg1 = userRhpg1 + userRhpg2
userRlpg1 = userRlpg1 + userRlpg2
userBlink1 = userBlink1 + userBlink2
userNotBlink1 = userNotBlink1 + userNotBlink2

# %%
for i in range(0, sum):
    user3Data.append([userHp1[i], userLp1[i], userLhpl1[i], userLlpl1[i], userHpl1[i], userLpl1[i], userLhpg1[i], userLlpg1[i], userRhpg1[i], userRlpg1[i], userBlink1[i], userNotBlink1[i]])
    user3Label.append(2)

# %%
import numpy as np

# %%
user1Data = np.array(user1Data)
user2Data = np.array(user2Data)
user3Data = np.array(user3Data)

user1Label = np.array(user1Label)
user2Label = np.array(user2Label)
user3Label = np.array(user3Label)

# %%
data = np.concatenate((user1Data, user2Data, user3Data), axis=0)

# %%
len(data)
# Out:
# 3239

# %%
label = np.concatenate((user1Label, user2Label, user3Label), axis=0)

# %%
len(label)
# Out:
# 3239

# %%
s = np.arange(data.shape[0])
np.random.shuffle(s)

# %%
data = data[s]
label = label[s]

# %%
label
# Out:
# array([2, 1, 1, ..., 1, 1, 1])

# %%
tempLabel = []

# %%
for i in range(0, len(label)):
    if(label[i] == 0):
        tempLabel.append([1, 0, 0])
    elif(label[i] == 1):
        tempLabel.append([0, 1, 0])
    else:
        tempLabel.append([0, 0, 1])

# %%
label = tempLabel

# %%
label = np.array(label)

# %%
train_data = data[:2500]
val_data = data[2500:]

train_label = label[:2500]
val_label = label[2500:]

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

val_data -= mean
val_data /= std

# %%
from keras import models
from keras import layers
from keras import regularizers
from keras import optimizers

# %%
def build_model(actiFunc, lossFunc, hidden, node, dropout):
    model = models.Sequential()
    
    model.add(layers.Dense(node[0], activation=actiFunc, input_shape=(12, )))
    model.add(layers.Dropout(dropout))
    
    if(hidden == 2):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    if(hidden == 3):
        model.add(layers.Dense(node[1], activation=actiFunc))
        model.add(layers.Dropout(dropout))
        model.add(layers.Dense(node[2], activation=actiFunc))
        model.add(layers.Dropout(dropout))
    
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(optimizer='rmsprop', loss=lossFunc, metrics=['accuracy'])
    return model

# %%
import numpy as np

num_epochs = 100


actiFunc = ['selu']
lossFunc = ['categorical_crossentropy']
hidden = [1, 2, 3]
#node = [[4, 4], [4, 8], [4, 16], [4, 32], [8, 4], [8, 8], [8, 16], [8, 32], [16, 4], [16, 8], [16, 16], [16, 32], [32, 4], [32, 8], [32, 16], [32, 32]]
node = [
    [4, 4, 4], [4, 4, 8], [4, 4, 16], [4, 4, 32], [4, 8, 4], [4, 8, 8], [4, 8, 16], [4, 8, 32], [4, 16, 4], [4, 16, 8], [4, 16, 16], [4, 16, 32], [4, 32, 4], [4, 32, 8], [4, 32, 16], [4, 32, 32],
    [8, 4, 4], [8, 4, 8], [8, 4, 16], [8, 4, 32], [8, 8, 4], [8, 8, 8], [8, 8, 16], [8, 8, 32], [8, 16, 4], [8, 16, 8], [8, 16, 16], [8, 16, 32], [8, 32, 4], [8, 32, 8], [8, 32, 16], [8, 32, 32],
    [16, 4, 4], [16, 4, 8], [16, 4, 16], [16, 4, 32], [16, 8, 4], [16, 8, 8], [16, 8, 16], [16, 8, 32], [16, 16, 4], [16, 16, 8], [16, 16, 16], [16, 16, 32], [16, 32, 4], [16, 32, 8], [16, 32, 16], [16, 32, 32],
    [32, 4, 4], [32, 4, 8], [32, 4, 16], [32, 4, 32], [32, 8, 4], [32, 8, 8], [32, 8, 16], [32, 8, 32], [32, 16, 4], [32, 16, 8], [32, 16, 16], [32, 16, 32], [32, 32, 4], [32, 32, 8], [32, 32, 16], [32, 32, 32]
]
batchSize = [512]
dropout = [0, 0.1, 0.3]

all_acc_histories = []
all_loss_histories = []

for i in range(len(actiFunc)):
    for j in range(len(lossFunc)):
        for k in range(len(hidden)):
            for l in range(len(node)):
                for m in range(len(batchSize)):
                    for n in range(len(dropout)):
                        print('Activation:', actiFunc[i] , '  Loss:', lossFunc[j] , '  HiddenLayer:', hidden[k] , '  Node:[', node[l][0], ',', node[l][1] , ',', node[l][2], ']  BatchSize:', batchSize[m], '  Dropout:', dropout[n])
    
                        model = build_model(actiFunc[i], lossFunc[j], hidden[k], node[l], dropout[n])
                        history = model.fit(train_data, train_label, validation_data=(val_data, val_label), epochs=num_epochs, batch_size=batchSize[m], verbose=False)
    
                        acc_history = history.history['val_acc']
                        all_acc_histories.append(acc_history)
                        loss_history = history.history['val_loss']
                        all_loss_histories.append(loss_history)
    
                        print('loss min :', min(loss_history), '  acc max:', max(acc_history))
                        print('loss mean :', np.mean(loss_history), '  acc mean:', np.mean(acc_history))
    
                        print()
# Out:
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6660822596053148   acc max: 0.8511502078163447
# loss mean : 0.9158210801457198   acc mean: 0.7019485796139108
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.554532053990035   acc max: 0.8646820060132482
# loss mean : 0.6885898479121626   acc mean: 0.7858863326826503
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5908303725380698   acc max: 0.8633288260403118
# loss mean : 0.829403001908843   acc mean: 0.7016644115917415
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5507774902293421   acc max: 0.8741542599359288
# loss mean : 0.7457626454885016   acc mean: 0.7380649519817595
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5550773146187985   acc max: 0.8687415437543505
# loss mean : 0.7543517887947201   acc mean: 0.7636129913532524
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6014171607278197   acc max: 0.8700947200171196
# loss mean : 0.773774216642883   acc mean: 0.7147767252943835
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6075788199175679   acc max: 0.8633288260403118
# loss mean : 0.7217329592488616   acc mean: 0.7776995935564276
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5616307532029159   acc max: 0.8700947302604076
# loss mean : 0.7139444239850942   acc mean: 0.7953585941123704
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5971474406361096   acc max: 0.8660351859861847
# loss mean : 0.7849418222025056   acc mean: 0.7574018943789689
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5778054198973557   acc max: 0.871447910233344
# loss mean : 0.745459343747454   acc mean: 0.7464140744743232
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5853412682051911   acc max: 0.8728010880285736
# loss mean : 0.7866743250782017   acc mean: 0.7498240865071346
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5883720505060137   acc max: 0.867388365959121
# loss mean : 0.8090998752522047   acc mean: 0.6905818661946564
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5501872652761023   acc max: 0.8741542540480546
# loss mean : 0.7524757377809373   acc mean: 0.7127334231775408
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5508266809990022   acc max: 0.8633288179747307
# loss mean : 0.8090995984729153   acc mean: 0.7259945862134352
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5409719589921231   acc max: 0.8700947200171196
# loss mean : 0.7157089480398795   acc mean: 0.8007036532947595
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5348252502442696   acc max: 0.8660351779206035
# loss mean : 0.7257353692666119   acc mean: 0.8001353166249351
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6019791774401323   acc max: 0.8592692839437958
# loss mean : 0.7471129171951537   acc mean: 0.7536535844674617
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5768770340008407   acc max: 0.8700947221948265
# loss mean : 0.684407329748061   acc mean: 0.834668471208283
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5641715630626808   acc max: 0.8687415400441831
# loss mean : 0.736085644676495   acc mean: 0.7891474943094873
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.552275540622226   acc max: 0.8700947200171196
# loss mean : 0.7199727071097803   acc mean: 0.8048443840335203
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.581994906168668   acc max: 0.8700947178394126
# loss mean : 0.7112466507496787   acc mean: 0.7860081167884063
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.649385745454383   acc max: 0.8552097337816984
# loss mean : 0.8653301798950512   acc mean: 0.698416778354909
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5915120788452912   acc max: 0.8619756438896685
# loss mean : 0.8803268313706325   acc mean: 0.6903518244130119
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6054698788587393   acc max: 0.8552097381371122
# loss mean : 0.7882341900092824   acc mean: 0.7300947206748677
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5726972359443065   acc max: 0.8687415378664762
# loss mean : 0.7757350004017755   acc mean: 0.7318403232081496
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5782841097195514   acc max: 0.867388368136828
# loss mean : 0.6920239949734511   acc mean: 0.8028822718357042
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6258727331445407   acc max: 0.8579160937275713
# loss mean : 0.8597663398935929   acc mean: 0.7239242224852994
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5654431570205378   acc max: 0.8633288157970237
# loss mean : 0.7203885366363356   acc mean: 0.7902841669849354
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.608409398221518   acc max: 0.8687415481097643
# loss mean : 0.7396512318657602   acc mean: 0.7786874151802513
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5775460578269339   acc max: 0.8687415356887693
# loss mean : 1.0189066489881689   acc mean: 0.6481055466227827
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5489755496281894   acc max: 0.8673883578935399
# loss mean : 0.6773021109033182   acc mean: 0.7965358569548644
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5877116723376778   acc max: 0.8552097440249865
# loss mean : 0.8082392221511782   acc mean: 0.7412043296899621
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.67182951754259   acc max: 0.8484438456927649
# loss mean : 0.8372644235010239   acc mean: 0.7423004056011229
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5958975386555043   acc max: 0.8660351779206035
# loss mean : 0.7442379604963553   acc mean: 0.7972124488302919
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5617584434510567   acc max: 0.871447899990056
# loss mean : 0.6991076358084102   acc mean: 0.8100947224859941
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5775924774242189   acc max: 0.8728010799629924
# loss mean : 0.6694426081032165   acc mean: 0.7984303107087442
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5751996976758211   acc max: 0.8741542540480546
# loss mean : 0.780152471761581   acc mean: 0.7374830852688891
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5925373084974225   acc max: 0.8660351838084777
# loss mean : 0.7822315661228073   acc mean: 0.7352774022299804
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5958130825033691   acc max: 0.867388365959121
# loss mean : 0.7877292323435111   acc mean: 0.7362922854199299
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5940329647031947   acc max: 0.8592692839437958
# loss mean : 0.7932050340770868   acc mean: 0.7767794319067818
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5804158618550178   acc max: 0.8741542621136357
# loss mean : 0.8794164385879475   acc mean: 0.6868064959394633
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6533443300262678   acc max: 0.8565629137546348
# loss mean : 0.847849024214022   acc mean: 0.6974424896136188
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6122327020268318   acc max: 0.8633288260403118
# loss mean : 0.7852353008004743   acc mean: 0.725615696887283
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.624899401958321   acc max: 0.8633288260403118
# loss mean : 0.9168724119114781   acc mean: 0.6234100138015934
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6086901073849411   acc max: 0.8687415400441831
# loss mean : 0.8575308864849025   acc mean: 0.7069282817036037
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.6159887903436756   acc max: 0.8511501960405962
# loss mean : 0.8267198161020655   acc mean: 0.6141001350050528
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.6048123138038005   acc max: 0.8660351903415985
# loss mean : 0.732087993306462   acc mean: 0.7776454681779115
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 4 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.6468136526734968   acc max: 0.8660351779206035
# loss mean : 0.9386647747035601   acc mean: 0.6512043288446893
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5283411102462686   acc max: 0.867388368136828
# loss mean : 0.7005686323165249   acc mean: 0.7822056838362927
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.49338847535872815   acc max: 0.8782138020324449
# loss mean : 0.5879693030472215   acc mean: 0.8163734770595464
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5631898710143743   acc max: 0.8687415481097643
# loss mean : 0.6640150888306523   acc mean: 0.8354668479254508
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5414406196674248   acc max: 0.8673883600712468
# loss mean : 0.7182355183056469   acc mean: 0.7811366720509707
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5560504033536485   acc max: 0.8741542621136357
# loss mean : 0.7381194454133108   acc mean: 0.7794181328035981
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.581925305607193   acc max: 0.867388368136828
# loss mean : 0.7714693559232357   acc mean: 0.7715832222030272
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5293132877317591   acc max: 0.8700947200171196
# loss mean : 0.6356442050706389   acc mean: 0.828687415769039
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5436519742495959   acc max: 0.8700947178394126
# loss mean : 0.6609356454002681   acc mean: 0.8110419485110065
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5610872391757527   acc max: 0.8687415481097643
# loss mean : 0.6839571157343817   acc mean: 0.7981326121991156
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5271026090452894   acc max: 0.871447899990056
# loss mean : 0.6526672780465368   acc mean: 0.8272124516855069
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5758469023304476   acc max: 0.871447899990056
# loss mean : 0.7458869526020083   acc mean: 0.7527469561800504
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5272921676242142   acc max: 0.8728010902062805
# loss mean : 0.6438311227813303   acc mean: 0.8162787538952371
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5526064408486847   acc max: 0.8714479080556371
# loss mean : 0.7019852569542009   acc mean: 0.8001488498248495
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.557144271020799   acc max: 0.8700947280827007
# loss mean : 0.6508546355572378   acc mean: 0.8307442490173775
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.587707183035204   acc max: 0.8687415378664762
# loss mean : 0.8015281088474802   acc mean: 0.7326386998577678
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5506826508513   acc max: 0.8673883578935399
# loss mean : 0.8006281610415978   acc mean: 0.7312178611829978
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5466671806227048   acc max: 0.8687415459320574
# loss mean : 0.7059779140575005   acc mean: 0.7879566974935898
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5611745777246271   acc max: 0.8728010902062805
# loss mean : 0.6606317312243182   acc mean: 0.8137212453909592
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5716205969231054   acc max: 0.8633288179747307
# loss mean : 0.6837009053640019   acc mean: 0.7859404587217369
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5362286003903866   acc max: 0.8700947302604076
# loss mean : 0.7137772292882728   acc mean: 0.7891610304979008
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.544325006185591   acc max: 0.8619756460673754
# loss mean : 0.6505834054664603   acc mean: 0.8208525016601419
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5446654910647659   acc max: 0.8606224639167321
# loss mean : 0.6726115843980334   acc mean: 0.8050473611772624
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5581236192112201   acc max: 0.8700947200171196
# loss mean : 0.6989717958559042   acc mean: 0.7794181307154193
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.522506631840227   acc max: 0.871447910233344
# loss mean : 0.7203026260389204   acc mean: 0.7652368068400673
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5411413700719325   acc max: 0.8660351800983104
# loss mean : 0.7544938210431229   acc mean: 0.7603247631525718
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5507543368494398   acc max: 0.8687415400441831
# loss mean : 0.7293601872214444   acc mean: 0.7456562921642774
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5408037276648701   acc max: 0.8741542621136357
# loss mean : 0.6811345138149751   acc mean: 0.7846684713203949
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5326363483043097   acc max: 0.8660351779206035
# loss mean : 0.6358417658360626   acc mean: 0.828958049998877
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.526122675696955   acc max: 0.8687415481097643
# loss mean : 0.7150090013418212   acc mean: 0.7751962112267384
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5461208425129541   acc max: 0.8714479080556371
# loss mean : 0.7940976204302701   acc mean: 0.7580108254107472
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.581332558304757   acc max: 0.8700947280827007
# loss mean : 0.9186772656706897   acc mean: 0.6881055458900249
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5572297417423884   acc max: 0.8646819979476671
# loss mean : 0.6999881390773558   acc mean: 0.817266574310837
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5257388058147507   acc max: 0.8741542599359288
# loss mean : 0.6995789151069114   acc mean: 0.7817861978731879
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5232833051229846   acc max: 0.875507434020991
# loss mean : 0.6583566974101436   acc mean: 0.796820026445776
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5454165233810796   acc max: 0.8728010799629924
# loss mean : 0.696310882895822   acc mean: 0.7900947230167094
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.551205923092704   acc max: 0.871447910233344
# loss mean : 0.6853637145255996   acc mean: 0.7968876871543261
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5213427250052982   acc max: 0.8714479080556371
# loss mean : 0.6414808152605942   acc mean: 0.8105142106170262
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5652659627355645   acc max: 0.871447899990056
# loss mean : 0.7737674202696398   acc mean: 0.7073207041611124
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5315679498873802   acc max: 0.8728010902062805
# loss mean : 0.6859493789709953   acc mean: 0.7859539939364336
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5255215125251688   acc max: 0.8728010902062805
# loss mean : 0.6432088636706743   acc mean: 0.8205412730860935
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5458860248932174   acc max: 0.8700947280827007
# loss mean : 0.6778635673900419   acc mean: 0.8220297688330465
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5542313448469758   acc max: 0.8741542701792169
# loss mean : 0.6695650550775504   acc mean: 0.8317050071433691
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5525356154480549   acc max: 0.8660351881638916
# loss mean : 0.6093727674076134   acc mean: 0.846238159981729
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5336658383577215   acc max: 0.8741542701792169
# loss mean : 0.6621604559127953   acc mean: 0.8041136675246353
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5588568982961859   acc max: 0.8728010843184062
# loss mean : 0.6578985740141552   acc mean: 0.8043572393100056
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5031918054988485   acc max: 0.8728010799629924
# loss mean : 0.7144728029080752   acc mean: 0.7701353175831261
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5306117528184986   acc max: 0.8700947280827007
# loss mean : 0.6700050011724837   acc mean: 0.8175778068745251
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 8 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5605484207686294   acc max: 0.8606224558511509
# loss mean : 0.7032199280445888   acc mean: 0.7989580504247397
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.488498141301017   acc max: 0.8768606139939273
# loss mean : 0.6039385630635996   acc mean: 0.8373883600474531
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5506822790280085   acc max: 0.8741542701792169
# loss mean : 0.676641517172647   acc mean: 0.8236400559758301
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5253968608234184   acc max: 0.8700947200171196
# loss mean : 0.6275186952605784   acc mean: 0.8358728003594648
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5046664780467063   acc max: 0.8728010799629924
# loss mean : 0.6311348951403278   acc mean: 0.8074966169990528
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5431094078475632   acc max: 0.8700947302604076
# loss mean : 0.6696884572191394   acc mean: 0.7886332924220413
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5646614200852721   acc max: 0.8700947302604076
# loss mean : 0.6601168130562012   acc mean: 0.8388903922810446
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5050684864530706   acc max: 0.8768606139939273
# loss mean : 0.6484300933969845   acc mean: 0.8097428949431331
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4853978829712926   acc max: 0.8795669739398001
# loss mean : 0.6349566246425993   acc mean: 0.7984709071076611
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5351034239922551   acc max: 0.871447910233344
# loss mean : 0.6241748114182275   acc mean: 0.8408930968338969
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.508076556722592   acc max: 0.8809201619783177
# loss mean : 0.6275749827891145   acc mean: 0.8280378904116011
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4808255750207036   acc max: 0.8809201619783177
# loss mean : 0.5896874743175765   acc mean: 0.857334235383145
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.546334711318087   acc max: 0.8741542621136357
# loss mean : 0.5942208253538819   acc mean: 0.8597293633061267
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5006274348666768   acc max: 0.8728010902062805
# loss mean : 0.5962384489247214   acc mean: 0.8450338291654085
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4753005778837914   acc max: 0.8836265219241904
# loss mean : 0.5882999865345768   acc mean: 0.8412178619720132
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5070010156689542   acc max: 0.871447910233344
# loss mean : 0.574021904545966   acc mean: 0.8462381599897943
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5143746348937245   acc max: 0.8714479021677629
# loss mean : 0.6211000798753538   acc mean: 0.8269147495068458
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.514082562294316   acc max: 0.8755074501521533
# loss mean : 0.6147447985765576   acc mean: 0.833491206957539
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5223343988555371   acc max: 0.8728010799629924
# loss mean : 0.6020465340270725   acc mean: 0.8581461434580478
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5160349100142596   acc max: 0.8782137939668637
# loss mean : 0.6053880093933283   acc mean: 0.8385926930471267
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5177147527992806   acc max: 0.8741542701792169
# loss mean : 0.5884943280120019   acc mean: 0.8561705024381129
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5262227099545108   acc max: 0.875507442086572
# loss mean : 0.6281486434825219   acc mean: 0.8357916095260032
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4939177803322169   acc max: 0.8768606220595085
# loss mean : 0.5867765418981505   acc mean: 0.8462787565588951
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5029442479710456   acc max: 0.8700947302604076
# loss mean : 0.6074004491135296   acc mean: 0.8318538579070517
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5125342963996856   acc max: 0.8795669739398001
# loss mean : 0.5886310851493289   acc mean: 0.8422733408365908
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5372926113731322   acc max: 0.8700947178394126
# loss mean : 0.6631836728265708   acc mean: 0.8202706338757588
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5115350597766158   acc max: 0.882273333885673
# loss mean : 0.5984604093404198   acc mean: 0.8398376193642618
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5203729835672856   acc max: 0.871447899990056
# loss mean : 0.633436546824943   acc mean: 0.8365899867000859
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4839760118311571   acc max: 0.875507442086572
# loss mean : 0.6313917372102505   acc mean: 0.8198376194521765
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5423420817668125   acc max: 0.8687415481097643
# loss mean : 0.5970865118560029   acc mean: 0.8559133953678753
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5326720872170547   acc max: 0.871447899990056
# loss mean : 0.5908980243728675   acc mean: 0.8604194897235813
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5163303670928346   acc max: 0.8700947280827007
# loss mean : 0.6171654645040007   acc mean: 0.8466576425164577
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5166200926081254   acc max: 0.8755074501521533
# loss mean : 0.6201371710677916   acc mean: 0.8285520977066159
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5261645453385958   acc max: 0.87415426800151
# loss mean : 0.6227217242787106   acc mean: 0.8176184030927729
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4802730386731428   acc max: 0.8741542642913426
# loss mean : 0.5816159433884613   acc mean: 0.850230038885496
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4997377216573981   acc max: 0.8782138042101518
# loss mean : 0.5929724273694545   acc mean: 0.8435588607857447
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5411010874946965   acc max: 0.8728010799629924
# loss mean : 0.624150655404318   acc mean: 0.8325439782761273
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5253537899747753   acc max: 0.860622466094439
# loss mean : 0.6172872011555064   acc mean: 0.8407036545783967
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5118739941284686   acc max: 0.8700947200171196
# loss mean : 0.6781922662532378   acc mean: 0.7959404599892431
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5299539126465865   acc max: 0.8728010902062805
# loss mean : 0.6208747193705245   acc mean: 0.8445060873717192
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5179507757394659   acc max: 0.8755074399088651
# loss mean : 0.6377972604142798   acc mean: 0.8284709062172211
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5044484717597497   acc max: 0.871447910233344
# loss mean : 0.6132855209397688   acc mean: 0.832029770751848
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.537624201287436   acc max: 0.871447899990056
# loss mean : 0.6310089850804802   acc mean: 0.8403518277914828
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4968461779038219   acc max: 0.8714479021677629
# loss mean : 0.6377127918556674   acc mean: 0.8303382954594244
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5095565378746579   acc max: 0.8755074479744464
# loss mean : 0.6154395667037074   acc mean: 0.8364817309766722
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.546250157491764   acc max: 0.8687415459320574
# loss mean : 0.6689577694989347   acc mean: 0.8177401897347505
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5079595800665622   acc max: 0.8809201619783177
# loss mean : 0.5825629498711781   acc mean: 0.8704194861142338
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5126248225468906   acc max: 0.8700947200171196
# loss mean : 0.7250057624536537   acc mean: 0.7911772676399016
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5456171647944211   acc max: 0.8728010799629924
# loss mean : 0.6271271664460716   acc mean: 0.831772663853407
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4390827039097901   acc max: 0.8836265160363163
# loss mean : 0.5254137993330723   acc mean: 0.8671853855457938
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4868502659629904   acc max: 0.8836265138586094
# loss mean : 0.5507093002863924   acc mean: 0.868741540913653
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5136550956069214   acc max: 0.8728010799629924
# loss mean : 0.5842737358824648   acc mean: 0.8487280113315552
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4772797520492977   acc max: 0.8809201619783177
# loss mean : 0.5870719333204752   acc mean: 0.8383626523255012
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.47241497757631645   acc max: 0.8836265138586094
# loss mean : 0.5486154716626234   acc mean: 0.866752366571207
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5330066749465643   acc max: 0.8728010799629924
# loss mean : 0.5881539992744126   acc mean: 0.8598646818889819
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4928612681622434   acc max: 0.8809201539127365
# loss mean : 0.5987772834171946   acc mean: 0.8475236806882414
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4758240415214363   acc max: 0.8809201539127365
# loss mean : 0.5557579818251007   acc mean: 0.860216507889905
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.526572267886589   acc max: 0.8741542701792169
# loss mean : 0.6023335369804392   acc mean: 0.8500405958109363
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48438602823043225   acc max: 0.8795669820053813
# loss mean : 0.5555811078316143   acc mean: 0.8635182677118642
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4884352838073596   acc max: 0.8809201619783177
# loss mean : 0.5733362780219002   acc mean: 0.8560081199222878
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5215839436315555   acc max: 0.8768606301250896
# loss mean : 0.5822185533787142   acc mean: 0.8524221944905745
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.465922361862353   acc max: 0.875507442086572
# loss mean : 0.5578064006171789   acc mean: 0.8535047355870915
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4765055580455331   acc max: 0.878213810098026
# loss mean : 0.5625570861549596   acc mean: 0.8664546701574196
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.500888345689993   acc max: 0.875507442086572
# loss mean : 0.5749512191796334   acc mean: 0.8561569708787379
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.48938319308831985   acc max: 0.8822733419512541
# loss mean : 0.5809224952783573   acc mean: 0.857023003305408
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.48988745596476596   acc max: 0.875507442086572
# loss mean : 0.5732579663198275   acc mean: 0.8488768625073893
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5312273623333571   acc max: 0.8741542701792169
# loss mean : 0.6040783431154143   acc mean: 0.8403112325237633
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4562502250135832   acc max: 0.8809201539127365
# loss mean : 0.5520144264720613   acc mean: 0.8533017594908668
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.49640916181030065   acc max: 0.8741542701792169
# loss mean : 0.5823026136713196   acc mean: 0.8484167803212981
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5129966334173902   acc max: 0.87415426800151
# loss mean : 0.5774112193558633   acc mean: 0.8539918817791465
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.46496596525099343   acc max: 0.8849796938315457
# loss mean : 0.5485543849616639   acc mean: 0.8677401890483695
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4943787082122369   acc max: 0.8755074501521533
# loss mean : 0.5778342401892632   acc mean: 0.8413125840309348
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.49377642473122746   acc max: 0.8755074501521533
# loss mean : 0.555655737344241   acc mean: 0.8660893100927584
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.47447149372875125   acc max: 0.878213810098026
# loss mean : 0.5764774637019037   acc mean: 0.8461028445819558
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4998646518051705   acc max: 0.8809201700438989
# loss mean : 0.5837989708244881   acc mean: 0.8554127216064883
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5173839364548659   acc max: 0.8728010902062805
# loss mean : 0.5959454644371596   acc mean: 0.8424627889198765
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4998845749198181   acc max: 0.875507442086572
# loss mean : 0.5672626214179037   acc mean: 0.8551962119292503
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5067989302746175   acc max: 0.8741542701792169
# loss mean : 0.5854483672528855   acc mean: 0.8509201618827406
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5304613299718245   acc max: 0.8728010880285736
# loss mean : 0.5963057141213681   acc mean: 0.8512990518150214
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.453108183505248   acc max: 0.8836265241018975
# loss mean : 0.5780488620664174   acc mean: 0.8439918815143941
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4960314301579828   acc max: 0.878213810098026
# loss mean : 0.5766716615151972   acc mean: 0.8571177247763484
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5308535194203399   acc max: 0.8728010799629924
# loss mean : 0.5954129830135867   acc mean: 0.8459945884044506
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4613727134361319   acc max: 0.8755074501521533
# loss mean : 0.568093231609129   acc mean: 0.8515561589304262
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5140757928520482   acc max: 0.8809201539127365
# loss mean : 0.5955149017828889   acc mean: 0.8453991883731018
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5236717338329723   acc max: 0.8741542599359288
# loss mean : 0.6037721707622478   acc mean: 0.8387415419218507
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4807357466269249   acc max: 0.882273333885673
# loss mean : 0.5670222361032953   acc mean: 0.8509066281835669
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5104690127992179   acc max: 0.8768606139939273
# loss mean : 0.5821966799033028   acc mean: 0.8498376181265982
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5287248789054293   acc max: 0.8768606301250896
# loss mean : 0.6040966021030616   acc mean: 0.8375236833978734
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4798435804324479   acc max: 0.8795669900709625
# loss mean : 0.5478205531093523   acc mean: 0.8671583259387979
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4974269427369186   acc max: 0.878213810098026
# loss mean : 0.5701395326368864   acc mean: 0.8625710431172819
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5165202337769598   acc max: 0.8755074399088651
# loss mean : 0.5470116430149994   acc mean: 0.868552102056182
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.47747569026095293   acc max: 0.8782138020324449
# loss mean : 0.5706933359372277   acc mean: 0.8563734791727287
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.518823669308416   acc max: 0.8755074399088651
# loss mean : 0.5841039013999725   acc mean: 0.8604194852060492
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5308369127920096   acc max: 0.871447910233344
# loss mean : 0.5730323003690201   acc mean: 0.8650744253638956
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.4682194201807531   acc max: 0.8809201619783177
# loss mean : 0.5541681118335711   acc mean: 0.8636671194825348
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.4926122461668693   acc max: 0.8822733419512541
# loss mean : 0.5764137239207757   acc mean: 0.854140730622818
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 1   Node:[ 32 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5146456935086334   acc max: 0.8755074399088651
# loss mean : 0.5964097290489122   acc mean: 0.844519619627154
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5160569377616552   acc max: 0.8741542701792169
# loss mean : 0.7803188695249442   acc mean: 0.7257239523404988
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5543199309799443   acc max: 0.871447910233344
# loss mean : 0.767316086172896   acc mean: 0.7548849801092089
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5552631817425379   acc max: 0.8714479080556371
# loss mean : 0.7833308279465919   acc mean: 0.7415155629922559
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.5195277470374462   acc max: 0.8660351859861847
# loss mean : 0.6943744215340995   acc mean: 0.7807983749282215
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.5318188564057924   acc max: 0.8714479080556371
# loss mean : 0.6780637226222492   acc mean: 0.8263464141706655
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 2   Node:[ 4 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.5910985286729423   acc max: 0.8714479021677629
# loss mean : 0.7765634424365421   acc mean: 0.7046143435915685
#
# ...
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30871280693072267   acc max: 0.9012178600399032
# loss mean : 0.4161268570809468   acc mean: 0.8734100149404536
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.47658992458906163   acc max: 0.8809201619783177
# loss mean : 0.5473059244609169   acc mean: 0.8656833574437968
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3241576612076353   acc max: 0.8958051460360319
# loss mean : 0.4537063789476561   acc mean: 0.8681461429841946
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.36275909508355414   acc max: 0.893098775846871
# loss mean : 0.4890990842654999   acc mean: 0.8741001326724864
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43371429575634907   acc max: 0.878213810098026
# loss mean : 0.5023731193095646   acc mean: 0.8661705000265044
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2750223310858374   acc max: 0.899864690310255
# loss mean : 0.39561187206851933   acc mean: 0.8732070365874789
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.31225640263221904   acc max: 0.9025710378351328
# loss mean : 0.42771844977051715   acc mean: 0.8711502028338319
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.40590988992838156   acc max: 0.882273333885673
# loss mean : 0.48217412477417143   acc mean: 0.8748579108416632
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3031925434833934   acc max: 0.8944519601752213
# loss mean : 0.3959877215610144   acc mean: 0.8796346411766315
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29940712238196915   acc max: 0.9052773999587125
# loss mean : 0.4079078866055435   acc mean: 0.8823410006740581
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.35091570931132654   acc max: 0.8903924159009983
# loss mean : 0.47631167305580496   acc mean: 0.8719079833561417
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.31585598314566604   acc max: 0.9039242280513572
# loss mean : 0.41895735676015994   acc mean: 0.8755074418244406
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3535106560777424   acc max: 0.886332875982189
# loss mean : 0.45940144346192663   acc mean: 0.8673883640189456
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43495761674699024   acc max: 0.889039243993643
# loss mean : 0.5282694729827899   acc mean: 0.8655074402750427
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3236416728715935   acc max: 0.8971583281866753
# loss mean : 0.42244836829794274   acc mean: 0.8730446547241593
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3295193425454048   acc max: 0.8971583260089683
# loss mean : 0.44127468411469173   acc mean: 0.8772665756021363
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.38744361196545046   acc max: 0.8849797040748338
# loss mean : 0.48429683994496786   acc mean: 0.8706630609177446
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.27770129741448024   acc max: 0.9039242302290642
# loss mean : 0.3673536115041928   acc mean: 0.8782679306263046
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.31051819472093545   acc max: 0.9012178578621963
# loss mean : 0.3798540945752387   acc mean: 0.8810148836674321
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3887732776640555   acc max: 0.8876860661984135
# loss mean : 0.4911849657148728   acc mean: 0.8719891751264204
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2764867665561191   acc max: 0.9052773940708382
# loss mean : 0.3455320970300731   acc mean: 0.886062246932067
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29375317039444576   acc max: 0.9120433020011014
# loss mean : 0.3621331188840859   acc mean: 0.8920027078399803
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 16 , 32 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3584624059871343   acc max: 0.8863328840477702
# loss mean : 0.4652714908159311   acc mean: 0.8713667115661871
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3460123581718527   acc max: 0.8795669739398001
# loss mean : 0.5054573085537137   acc mean: 0.8255615685029265
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3896046066316442   acc max: 0.8903924180787052
# loss mean : 0.4711462724039454   acc mean: 0.8740189420983335
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.43994384487846383   acc max: 0.8700947280827007
# loss mean : 0.5426867015153694   acc mean: 0.8345196189452088
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.31008817555939877   acc max: 0.9025710400128397
# loss mean : 0.39470317233157265   acc mean: 0.8837618397892086
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.35920687154923464   acc max: 0.8890392461713499
# loss mean : 0.47128323217488427   acc mean: 0.8666576446909383
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.45984598248188807   acc max: 0.878213810098026
# loss mean : 0.5561353927149018   acc mean: 0.8549391079791827
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.34205083651858836   acc max: 0.8944519579975143
# loss mean : 0.4861016716415892   acc mean: 0.8747090662445203
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3434569112180212   acc max: 0.8930987780245779
# loss mean : 0.4483699630335962   acc mean: 0.868903924953873
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4074191575685922   acc max: 0.8849796938315457
# loss mean : 0.5086259809217047   acc mean: 0.852801083625573
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.34245696720315577   acc max: 0.8930987860901591
# loss mean : 0.4595012488013514   acc mean: 0.8735453305797745
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.35035312619357695   acc max: 0.8944519682408024
# loss mean : 0.4358855159744035   acc mean: 0.876373480047844
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 4 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4215305057204302   acc max: 0.8822733419512541
# loss mean : 0.5102931558964863   acc mean: 0.8589309897119525
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.37085735563980227   acc max: 0.8958051482137388
# loss mean : 0.475477059142354   acc mean: 0.878538565778442
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.32854426766119404   acc max: 0.8985114979163236
# loss mean : 0.41933963093165616   acc mean: 0.878958051021593
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4314456077164016   acc max: 0.8755074501521533
# loss mean : 0.5368362970942573   acc mean: 0.857780784478207
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.316272019412424   acc max: 0.8985114979163236
# loss mean : 0.42812506732945516   acc mean: 0.8713937729314797
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.30656398955798114   acc max: 0.8985114979163236
# loss mean : 0.3829208342700753   acc mean: 0.8820433016131468
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4052316335121898   acc max: 0.8849797040748338
# loss mean : 0.49148836356941833   acc mean: 0.8714479051262177
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3071564425876886   acc max: 0.9012178600399032
# loss mean : 0.4130645366248968   acc mean: 0.875047361501499
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.31507360406915613   acc max: 0.8958051503914457
# loss mean : 0.41872225865096624   acc mean: 0.8734776722727513
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.41720650011373633   acc max: 0.882273344128961
# loss mean : 0.4995779246672564   acc mean: 0.8663058188009165
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2862156066181534   acc max: 0.8958051460360319
# loss mean : 0.36878633999211546   acc mean: 0.8785115004231066
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3024292001462918   acc max: 0.9039242302290642
# loss mean : 0.4171239694594046   acc mean: 0.8737212436907346
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 8 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.373157012365829   acc max: 0.8863328840477702
# loss mean : 0.47303627900164236   acc mean: 0.8718132619348044
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3041127836671992   acc max: 0.8944519704185093
# loss mean : 0.4196768144611899   acc mean: 0.865561570530412
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2957663012212281   acc max: 0.9079837701478733
# loss mean : 0.40628001035630945   acc mean: 0.8858998667830866
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4057823247774044   acc max: 0.8849797040748338
# loss mean : 0.4884299059339242   acc mean: 0.8734506072315701
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.3028533573644248   acc max: 0.8985115059819048
# loss mean : 0.38668367919563773   acc mean: 0.8791745595317407
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3125964978631682   acc max: 0.9025710480784208
# loss mean : 0.39055456598169586   acc mean: 0.8845060910496241
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.4323008300809641   acc max: 0.8836265241018975
# loss mean : 0.5237098876654053   acc mean: 0.8647090658372086
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0
# loss min : 0.289096164687238   acc max: 0.9079837620822921
# loss mean : 0.3709217586653643   acc mean: 0.8822733426142448
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.3120232292215298   acc max: 0.9025710502561277
# loss mean : 0.39994548982914147   acc mean: 0.8871583230319622
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 16 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.37082901705908355   acc max: 0.8890392461713499
# loss mean : 0.4731187124286195   acc mean: 0.8734912048834748
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0
# loss min : 0.29056002048420165   acc max: 0.9093369501208097
# loss mean : 0.37777469212050685   acc mean: 0.88232747139079
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29357213378759134   acc max: 0.9052774102020006
# loss mean : 0.37618916588037676   acc mean: 0.8837347763381564
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 16 , 32 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3358608152369524   acc max: 0.8917456061172228
# loss mean : 0.44291802720707385   acc mean: 0.8756968859866445
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0
# loss min : 0.2736432689855805   acc max: 0.9066305740437747
# loss mean : 0.3708161468422783   acc mean: 0.8890933707941207
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.2891036938669233   acc max: 0.8985115081596117
# loss mean : 0.38474723475187494   acc mean: 0.8819079830867514
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 4 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.3825970739731124   acc max: 0.8836265241018975
# loss mean : 0.4849495912186992   acc mean: 0.8755886321727576
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0
# loss min : 0.28210593467636264   acc max: 0.9052773999587125
# loss mean : 0.3394531163194182   acc mean: 0.8894722616075663
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.1
# loss min : 0.29438775959292346   acc max: 0.9093369420552286
# loss mean : 0.358774262030328   acc mean: 0.8919350480194503
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 8 ]  BatchSize: 512   Dropout: 0.3
# loss min : 0.34942307189127103   acc max: 0.8890392359280619
# loss mean : 0.4466691746743187   acc mean: 0.878416778923533
#
# Activation: selu   Loss: categorical_crossentropy   HiddenLayer: 3   Node:[ 32 , 32 , 16 ]  BatchSize: 512   Dropout: 0
